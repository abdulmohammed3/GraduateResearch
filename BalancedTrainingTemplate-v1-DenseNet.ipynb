# %%
import os

from platform import python_version
import warnings
import time
import datetime as dt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import multiprocessing as mp
import shutil

from imblearn.keras import BalancedBatchGenerator
from imblearn.under_sampling import RandomUnderSampler

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.densenet import DenseNet121, preprocess_input, decode_predictions
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras import regularizers

import pandas as pd
import numpy as np
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go

from PIL import Image
import xml.etree.ElementTree as ET
import psutil
import random

warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
img_size = 96
epochs = 75
batch_size = 32
testsplit = .25
targetx = 96
targety = 96
learning_rate = 0.0001
classes = 7
seed = 23
print(seed)
# Out:
# 23

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from collections import Counter

model_name = 'DNetBalancedmodel.keras'

# Define two different ImageDataGenerators with their respective directories
datagen1 = ImageDataGenerator(
        rescale=1./255,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        fill_mode='nearest',
        preprocessing_function=preprocess_input
)

datagen2 = ImageDataGenerator(
        rescale=1./255,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        fill_mode='nearest',
        preprocessing_function=preprocess_input
)

train_dir1 = 'KDEFMF/MaleBalancedTraining'
train_dir2 = 'KDEFMF/FemaleBalancedTraining'
val_dir1 = 'KDEFMF/MaleBalancedValidation'
val_dir2 = 'KDEFMF/FemaleBalancedValidation'

# Create two separate generators using different directories
train_generator1 = datagen1.flow_from_directory(
    train_dir1,
    target_size=(targetx,targety),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
    seed=seed
)
validation_generator1 = datagen1.flow_from_directory(
    val_dir1,
    target_size=(targetx,targety),
    batch_size=batch_size,
    class_mode='categorical',
)
validation_generator2 = datagen2.flow_from_directory(
    val_dir2,
    target_size=(targetx,targety),
    batch_size=batch_size,
    class_mode='categorical',
)

train_generator2 = datagen2.flow_from_directory(
    train_dir2,
    target_size=(targetx,targety),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
    seed=seed
)

total_train_samples = len(train_generator1.filenames) + len(train_generator2.filenames)
total_validation_samples = len(validation_generator1.filenames) + len(validation_generator2.filenames)

# Combine labels from both generators
all_labels = list(train_generator1.classes) + list(train_generator2.classes)

# Get class indices (assuming they are the same for both generators)
class_indices = train_generator1.class_indices
index_to_class = {v: k for k, v in class_indices.items()}

# Count the number of occurrences of each class
class_counts = Counter(all_labels)

# Print the number of images per class
for class_index, count in class_counts.items():
    class_name = index_to_class[class_index]
    print(f"Class '{class_name}' has {count} images.")
    
def combined_generator(gen1, gen2, num_batches):
    while True:
        try:
            batch1_x, batch1_y = next(gen1)
            batch2_x, batch2_y = next(gen2)

            combined_x = np.concatenate((batch1_x, batch2_x), axis=0)
            combined_y = np.concatenate((batch1_y, batch2_y), axis=0)

            yield combined_x, combined_y
        except StopIteration as e:
            print("Generator exhausted or encountered an error:", e)
            break
# Out:
# Found 1120 images belonging to 7 classes.
# Found 280 images belonging to 7 classes.
# Found 280 images belonging to 7 classes.
# Found 1120 images belonging to 7 classes.
# Class 'angry' has 320 images.
# Class 'disgust' has 320 images.
# Class 'fear' has 320 images.
# Class 'happy' has 320 images.
# Class 'neutral' has 320 images.
# Class 'sad' has 320 images.
# Class 'surprise' has 320 images.

# %%
base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(targetx, targety, 3))

# Custom Layers neccesarry to acheive high acurracy 
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Flatten() (x)
x = BatchNormalization()(x)
x=Dropout(0.3)(x)
x = Dense(512, activation='relu',  kernel_initializer=glorot_uniform(seed),kernel_regularizer=regularizers.L2(0.001),activity_regularizer=regularizers.L2(1e-4), bias_initializer='zeros')(x)
x = BatchNormalization()(x)
x=Dropout(0.3)(x)
x = Dense(256, activation='relu',  kernel_initializer=glorot_uniform(seed),kernel_regularizer=regularizers.L2(0.001),activity_regularizer=regularizers.L2(1e-4), bias_initializer='zeros')(x)
x = BatchNormalization()(x)
x=Dropout(0.3)(x)
x = Dense(128, activation='relu',  kernel_initializer=glorot_uniform(seed),kernel_regularizer=regularizers.L2(0.001),activity_regularizer=regularizers.L2(1e-4), bias_initializer='zeros')(x)
x = BatchNormalization()(x)
x=Dropout(0.3)(x)
predictions = Dense(classes, activation='softmax', kernel_initializer='random_uniform', bias_initializer='zeros')(x)

model = tf.keras.Model(inputs=base_model.input, outputs=predictions)
optimizer = Adam(learning_rate=learning_rate)
loss = "categorical_crossentropy"

for layer in model.layers:
    layer.trainable = True

model.compile(optimizer=optimizer,
              loss=loss,
              metrics=["accuracy"])

# %%
# Define the number of batches you want from each generator
num_batches_per_gen = 100  # Adjust as needed

# Use the combined generator for training
combined_train_generator = combined_generator(train_generator1, train_generator2, num_batches_per_gen)

# Use the combined generator for validation
combined_validation_generator = combined_generator(validation_generator1, validation_generator2, num_batches_per_gen)


steps_per_epoch = total_train_samples // (2 * 32)
validation_steps = total_validation_samples // (2 * 32)

# Ensure correct optimizer and loss function
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure ModelCheckpoint is correctly configured used for callback to save the best value based on val_accuracy
checkpoint = ModelCheckpoint(model_name, monitor='val_accuracy', save_best_only=True, verbose=1)

# Train the model with callbacks
history = model.fit(
    combined_train_generator,
    steps_per_epoch=steps_per_epoch,
    validation_data=combined_validation_generator,
    validation_steps=validation_steps,
    epochs=epochs,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.1635 - loss: 7.1653
# Epoch 1: val_accuracy improved from -inf to 0.15039, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 121s 2s/step - accuracy: 0.1637 - loss: 7.1623 - val_accuracy: 0.1504 - val_loss: 7.9994
# Epoch 2/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2033 - loss: 6.7131
# Epoch 2: val_accuracy improved from 0.15039 to 0.15726, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.2035 - loss: 6.7101 - val_accuracy: 0.1573 - val_loss: 7.0460
# Epoch 3/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2573 - loss: 6.2277
# Epoch 3: val_accuracy did not improve from 0.15726
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.2573 - loss: 6.2243 - val_accuracy: 0.1431 - val_loss: 5.6601
# Epoch 4/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2932 - loss: 5.7237
# Epoch 4: val_accuracy did not improve from 0.15726
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.2936 - loss: 5.7211 - val_accuracy: 0.1290 - val_loss: 5.1159
# Epoch 5/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3594 - loss: 5.3381
# Epoch 5: val_accuracy did not improve from 0.15726
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.3593 - loss: 5.3361 - val_accuracy: 0.1512 - val_loss: 3.9361
# Epoch 6/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3934 - loss: 5.0459
# Epoch 6: val_accuracy did not improve from 0.15726
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 0.3936 - loss: 5.0441 - val_accuracy: 0.1310 - val_loss: 3.7038
# Epoch 7/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.4581 - loss: 4.7594
# Epoch 7: val_accuracy did not improve from 0.15726
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.4582 - loss: 4.7583 - val_accuracy: 0.1351 - val_loss: 3.7809
# Epoch 8/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5063 - loss: 4.5386
# Epoch 8: val_accuracy did not improve from 0.15726
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.5065 - loss: 4.5372 - val_accuracy: 0.1411 - val_loss: 3.5128
# Epoch 9/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5469 - loss: 4.3548
# Epoch 9: val_accuracy did not improve from 0.15726
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.5469 - loss: 4.3531 - val_accuracy: 0.1310 - val_loss: 3.4592
# Epoch 10/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5780 - loss: 4.1498
# Epoch 10: val_accuracy did not improve from 0.15726
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.5780 - loss: 4.1485 - val_accuracy: 0.1445 - val_loss: 3.5224
# Epoch 11/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6090 - loss: 3.9760
# Epoch 11: val_accuracy did not improve from 0.15726
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.6091 - loss: 3.9750 - val_accuracy: 0.1512 - val_loss: 3.4809
# Epoch 12/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5996 - loss: 3.8143
# Epoch 12: val_accuracy improved from 0.15726 to 0.16935, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.6001 - loss: 3.8129 - val_accuracy: 0.1694 - val_loss: 3.3994
# Epoch 13/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6354 - loss: 3.6376
# Epoch 13: val_accuracy did not improve from 0.16935
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.6364 - loss: 3.6358 - val_accuracy: 0.1512 - val_loss: 3.3299
# Epoch 14/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6813 - loss: 3.4871
# Epoch 14: val_accuracy did not improve from 0.16935
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.6815 - loss: 3.4859 - val_accuracy: 0.1532 - val_loss: 3.3431
# Epoch 15/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7325 - loss: 3.3172
# Epoch 15: val_accuracy did not improve from 0.16935
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.7323 - loss: 3.3166 - val_accuracy: 0.1452 - val_loss: 3.3739
# Epoch 16/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7344 - loss: 3.1866
# Epoch 16: val_accuracy improved from 0.16935 to 0.17137, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.7346 - loss: 3.1855 - val_accuracy: 0.1714 - val_loss: 3.4196
# Epoch 17/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7562 - loss: 3.0658
# Epoch 17: val_accuracy improved from 0.17137 to 0.21169, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.7563 - loss: 3.0647 - val_accuracy: 0.2117 - val_loss: 3.3964
# Epoch 18/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7742 - loss: 2.9555
# Epoch 18: val_accuracy did not improve from 0.21169
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.7738 - loss: 2.9565 - val_accuracy: 0.1593 - val_loss: 3.3439
# Epoch 19/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7638 - loss: 2.8909
# Epoch 19: val_accuracy improved from 0.21169 to 0.23633, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.7642 - loss: 2.8895 - val_accuracy: 0.2363 - val_loss: 3.4626
# Epoch 20/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7852 - loss: 2.7448
# Epoch 20: val_accuracy did not improve from 0.23633
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.7853 - loss: 2.7442 - val_accuracy: 0.2137 - val_loss: 3.5269
# Epoch 21/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8280 - loss: 2.6183
# Epoch 21: val_accuracy did not improve from 0.23633
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8280 - loss: 2.6176 - val_accuracy: 0.1774 - val_loss: 3.5115
# Epoch 22/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8399 - loss: 2.5434
# Epoch 22: val_accuracy did not improve from 0.23633
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8392 - loss: 2.5447 - val_accuracy: 0.2339 - val_loss: 7.9746
# Epoch 23/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8117 - loss: 2.5201
# Epoch 23: val_accuracy improved from 0.23633 to 0.23790, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8114 - loss: 2.5200 - val_accuracy: 0.2379 - val_loss: 8.0090
# Epoch 24/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8234 - loss: 2.4171
# Epoch 24: val_accuracy improved from 0.23790 to 0.31653, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8239 - loss: 2.4160 - val_accuracy: 0.3165 - val_loss: 2.7927
# Epoch 25/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8811 - loss: 2.2786
# Epoch 25: val_accuracy improved from 0.31653 to 0.43347, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8807 - loss: 2.2781 - val_accuracy: 0.4335 - val_loss: 4.7618
# Epoch 26/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8345 - loss: 2.2878
# Epoch 26: val_accuracy improved from 0.43347 to 0.50403, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.8345 - loss: 2.2875 - val_accuracy: 0.5040 - val_loss: 4.9561
# Epoch 27/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8494 - loss: 2.2061
# Epoch 27: val_accuracy improved from 0.50403 to 0.55645, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8498 - loss: 2.2051 - val_accuracy: 0.5565 - val_loss: 2.3318
# Epoch 28/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8698 - loss: 2.1171
# Epoch 28: val_accuracy improved from 0.55645 to 0.65820, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8698 - loss: 2.1165 - val_accuracy: 0.6582 - val_loss: 2.0482
# Epoch 29/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8910 - loss: 2.0076
# Epoch 29: val_accuracy did not improve from 0.65820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8909 - loss: 2.0079 - val_accuracy: 0.6008 - val_loss: 2.1078
# Epoch 30/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9123 - loss: 1.9142
# Epoch 30: val_accuracy did not improve from 0.65820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9121 - loss: 1.9141 - val_accuracy: 0.6532 - val_loss: 2.3652
# Epoch 31/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8855 - loss: 1.9307
# Epoch 31: val_accuracy did not improve from 0.65820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.8853 - loss: 1.9305 - val_accuracy: 0.4234 - val_loss: 2.4693
# Epoch 32/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8291 - loss: 2.0382
# Epoch 32: val_accuracy did not improve from 0.65820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.8287 - loss: 2.0394 - val_accuracy: 0.4738 - val_loss: 29.1172
# Epoch 33/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8337 - loss: 1.9884
# Epoch 33: val_accuracy improved from 0.65820 to 0.73589, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8338 - loss: 1.9877 - val_accuracy: 0.7359 - val_loss: 19.2524
# Epoch 34/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8691 - loss: 1.8955
# Epoch 34: val_accuracy did not improve from 0.73589
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.8691 - loss: 1.8945 - val_accuracy: 0.7157 - val_loss: 5.5619
# Epoch 35/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8728 - loss: 1.8386
# Epoch 35: val_accuracy did not improve from 0.73589
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.8730 - loss: 1.8379 - val_accuracy: 0.5504 - val_loss: 2.5625
# Epoch 36/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8878 - loss: 1.7673
# Epoch 36: val_accuracy improved from 0.73589 to 0.77218, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8878 - loss: 1.7671 - val_accuracy: 0.7722 - val_loss: 1.8916
# Epoch 37/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9053 - loss: 1.7258
# Epoch 37: val_accuracy improved from 0.77218 to 0.82422, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9053 - loss: 1.7255 - val_accuracy: 0.8242 - val_loss: 4.0352
# Epoch 38/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9022 - loss: 1.6539
# Epoch 38: val_accuracy did not improve from 0.82422
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9021 - loss: 1.6545 - val_accuracy: 0.6794 - val_loss: 43.3689
# Epoch 39/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8988 - loss: 1.6859
# Epoch 39: val_accuracy did not improve from 0.82422
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.8986 - loss: 1.6854 - val_accuracy: 0.8024 - val_loss: 26.6866
# Epoch 40/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8967 - loss: 1.6358
# Epoch 40: val_accuracy improved from 0.82422 to 0.84476, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8963 - loss: 1.6369 - val_accuracy: 0.8448 - val_loss: 5.6840
# Epoch 41/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9124 - loss: 1.5887
# Epoch 41: val_accuracy improved from 0.84476 to 0.84677, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.9123 - loss: 1.5883 - val_accuracy: 0.8468 - val_loss: 20.6258
# Epoch 42/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9077 - loss: 1.5608
# Epoch 42: val_accuracy did not improve from 0.84677
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9076 - loss: 1.5606 - val_accuracy: 0.8448 - val_loss: 20.6146
# Epoch 43/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9260 - loss: 1.4891
# Epoch 43: val_accuracy did not improve from 0.84677
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9256 - loss: 1.4898 - val_accuracy: 0.7802 - val_loss: 38.8060
# Epoch 44/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9057 - loss: 1.5041
# Epoch 44: val_accuracy did not improve from 0.84677
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9057 - loss: 1.5042 - val_accuracy: 0.8105 - val_loss: 7.9451
# Epoch 45/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9251 - loss: 1.4604
# Epoch 45: val_accuracy did not improve from 0.84677
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9249 - loss: 1.4605 - val_accuracy: 0.8024 - val_loss: 6.0115
# Epoch 46/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9157 - loss: 1.4833
# Epoch 46: val_accuracy improved from 0.84677 to 0.90820, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9158 - loss: 1.4830 - val_accuracy: 0.9082 - val_loss: 1.9734
# Epoch 47/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9220 - loss: 1.4131
# Epoch 47: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9221 - loss: 1.4131 - val_accuracy: 0.8750 - val_loss: 3.5370
# Epoch 48/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9323 - loss: 1.4045
# Epoch 48: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9321 - loss: 1.4045 - val_accuracy: 0.8931 - val_loss: 1.3912
# Epoch 49/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9336 - loss: 1.3892
# Epoch 49: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9335 - loss: 1.3892 - val_accuracy: 0.8810 - val_loss: 7.3336
# Epoch 50/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9337 - loss: 1.3476
# Epoch 50: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9337 - loss: 1.3475 - val_accuracy: 0.8427 - val_loss: 3.0887
# Epoch 51/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9307 - loss: 1.3379
# Epoch 51: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9307 - loss: 1.3381 - val_accuracy: 0.8790 - val_loss: 12.3219
# Epoch 52/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9218 - loss: 1.3504
# Epoch 52: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9217 - loss: 1.3505 - val_accuracy: 0.9052 - val_loss: 1.6979
# Epoch 53/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9396 - loss: 1.2977
# Epoch 53: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9395 - loss: 1.2977 - val_accuracy: 0.8528 - val_loss: 1.4348
# Epoch 54/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9058 - loss: 1.4019
# Epoch 54: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9056 - loss: 1.4028 - val_accuracy: 0.8105 - val_loss: 1.5863
# Epoch 55/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9125 - loss: 1.3677
# Epoch 55: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9126 - loss: 1.3673 - val_accuracy: 0.8516 - val_loss: 1.3603
# Epoch 56/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9329 - loss: 1.2975
# Epoch 56: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9326 - loss: 1.2981 - val_accuracy: 0.8629 - val_loss: 1.3351
# Epoch 57/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8874 - loss: 1.4097
# Epoch 57: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.8877 - loss: 1.4090 - val_accuracy: 0.8810 - val_loss: 1.2796
# Epoch 58/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9169 - loss: 1.3165
# Epoch 58: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9169 - loss: 1.3166 - val_accuracy: 0.8851 - val_loss: 1.2371
# Epoch 59/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9364 - loss: 1.2651
# Epoch 59: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9362 - loss: 1.2650 - val_accuracy: 0.8589 - val_loss: 1.3025
# Epoch 60/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9351 - loss: 1.2259
# Epoch 60: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9352 - loss: 1.2257 - val_accuracy: 0.8790 - val_loss: 1.2887
# Epoch 61/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9411 - loss: 1.2062
# Epoch 61: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 48s 1s/step - accuracy: 0.9405 - loss: 1.2076 - val_accuracy: 0.3911 - val_loss: 3727.7275
# Epoch 62/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9114 - loss: 1.3015
# Epoch 62: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9116 - loss: 1.3010 - val_accuracy: 0.7520 - val_loss: 56.9859
# Epoch 63/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9322 - loss: 1.2452
# Epoch 63: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.9316 - loss: 1.2469 - val_accuracy: 0.7359 - val_loss: 1.5831
# Epoch 64/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8532 - loss: 1.4944
# Epoch 64: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.8534 - loss: 1.4936 - val_accuracy: 0.5801 - val_loss: 90.1078
# Epoch 65/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8955 - loss: 1.3169
# Epoch 65: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.8956 - loss: 1.3167 - val_accuracy: 0.8629 - val_loss: 1.2771
# Epoch 66/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8818 - loss: 1.3492
# Epoch 66: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 47s 1s/step - accuracy: 0.8814 - loss: 1.3501 - val_accuracy: 0.6996 - val_loss: 1.6242
# Epoch 67/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8307 - loss: 1.5189
# Epoch 67: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8305 - loss: 1.5196 - val_accuracy: 0.7923 - val_loss: 1.5209
# Epoch 68/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8514 - loss: 1.3922
# Epoch 68: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.8515 - loss: 1.3923 - val_accuracy: 0.8145 - val_loss: 2.4593
# Epoch 69/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8917 - loss: 1.2926
# Epoch 69: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.8914 - loss: 1.2936 - val_accuracy: 0.7702 - val_loss: 1.5135
# Epoch 70/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8790 - loss: 1.3343
# Epoch 70: val_accuracy did not improve from 0.90820
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 46s 1s/step - accuracy: 0.8790 - loss: 1.3341 - val_accuracy: 0.8972 - val_loss: 1.9787
# Epoch 71/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9070 - loss: 1.2675
# Epoch 71: val_accuracy improved from 0.90820 to 0.92339, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9070 - loss: 1.2673 - val_accuracy: 0.9234 - val_loss: 2.3608
# Epoch 72/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9337 - loss: 1.1807
# Epoch 72: val_accuracy did not improve from 0.92339
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9336 - loss: 1.1811 - val_accuracy: 0.8669 - val_loss: 1.2610
# Epoch 73/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8928 - loss: 1.2788
# Epoch 73: val_accuracy did not improve from 0.92339
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.8931 - loss: 1.2779 - val_accuracy: 0.8320 - val_loss: 1.3995
# Epoch 74/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9086 - loss: 1.2155
# Epoch 74: val_accuracy did not improve from 0.92339
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 44s 1s/step - accuracy: 0.9084 - loss: 1.2159 - val_accuracy: 0.8750 - val_loss: 1.2156
# Epoch 75/75
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9128 - loss: 1.1903
# Epoch 75: val_accuracy improved from 0.92339 to 0.92944, saving model to DNetBalancedmodel.keras
# 35/35 ━━━━━━━━━━━━━━━━━━━━ 45s 1s/step - accuracy: 0.9126 - loss: 1.1913 - val_accuracy: 0.9294 - val_loss: 1.0668

# %%
# Define the number of batches you want from each generator
num_batches_per_gen = 100  # Adjust as needed

# Use the combined generator for training
combined_train_generator = combined_generator(train_generator1, train_generator2, num_batches_per_gen)

# Use the combined generator for validation
combined_validation_generator = combined_generator(validation_generator1, validation_generator2, num_batches_per_gen)


steps_per_epoch = total_train_samples // (2 * 32)
validation_steps = total_validation_samples // (2 * 32)

# %%
model = tf.keras.models.load_model(model_name)

# %%
# Collect predictions and true labels
y_true = []
y_pred = []

for batch_x, batch_y in combined_validation_generator:
    # Make predictions
    predictions = model.predict(batch_x)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = np.argmax(batch_y, axis=1)
    
    # Append to lists
    y_true.extend(true_classes)
    y_pred.extend(predicted_classes)
    
    # Stop if you have processed the entire validation set
    if len(y_true) >= total_validation_samples:
        break

# Generate classification report
report = classification_report(y_true, y_pred, target_names=validation_generator1.class_indices.keys())
print(report)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 197ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 193ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
#               precision    recall  f1-score   support
#
#        angry       0.95      0.87      0.91        87
#      disgust       0.90      0.89      0.89        81
#         fear       0.82      0.77      0.79        70
#        happy       0.95      1.00      0.98        82
#      neutral       0.91      0.97      0.94        80
#          sad       0.91      0.86      0.88        85
#     surprise       0.89      0.97      0.93        75
#
#     accuracy                           0.91       560
#    macro avg       0.90      0.91      0.90       560
# weighted avg       0.91      0.91      0.91       560

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report

# Assuming you have the model and validation generators defined
# validation_generator1 and validation_generator2
# Also assuming the target_names are the same for both generators

# Function to generate and print classification report
def generate_classification_report(generator, generator_name):
    y_true = []
    y_pred = []

    for batch_x, batch_y in generator:
        # Generate predictions
        predictions = model.predict(batch_x)
        predicted_classes = np.argmax(predictions, axis=1)
        true_classes = np.argmax(batch_y, axis=1)

        # Collect predictions and true labels
        y_true.extend(true_classes)
        y_pred.extend(predicted_classes)

        # Break if processed all samples
        if len(y_true) >= generator.samples:
            break

    # Generate and print the classification report
    target_names = list(generator.class_indices.keys())
    report = classification_report(y_true, y_pred, target_names=target_names)
    print(f"Classification Report for {generator_name}:\n{report}")

# Generate and print classification reports for both validation generators
generate_classification_report(validation_generator1, "Validation Generator 1")
generate_classification_report(validation_generator2, "Validation Generator 2")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 194ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 200ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 196ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 172ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# Classification Report for Validation Generator 1:
#               precision    recall  f1-score   support
#
#        angry       1.00      0.92      0.96        36
#      disgust       0.83      0.81      0.82        36
#         fear       0.86      0.71      0.78        45
#        happy       0.95      1.00      0.97        39
#      neutral       0.79      0.97      0.87        39
#          sad       0.89      0.80      0.84        40
#     surprise       0.84      0.93      0.88        45
#
#     accuracy                           0.88       280
#    macro avg       0.88      0.88      0.88       280
# weighted avg       0.88      0.88      0.87       280
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 195ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 191ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 197ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 192ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step
# Classification Report for Validation Generator 2:
#               precision    recall  f1-score   support
#
#        angry       0.88      0.88      0.88        43
#      disgust       0.97      0.87      0.92        39
#         fear       0.92      0.83      0.87        41
#        happy       0.98      1.00      0.99        41
#      neutral       0.98      1.00      0.99        40
#          sad       0.94      0.92      0.93        36
#     surprise       0.85      1.00      0.92        40
#
#     accuracy                           0.93       280
#    macro avg       0.93      0.93      0.93       280
# weighted avg       0.93      0.93      0.93       280

# %%
Y_pred = model.predict(validation_generator1)
y_pred = np.argmax(Y_pred, axis=1)
y_true=validation_generator1.classes

Y_pred1 = model.predict(validation_generator2)
y_pred1 = np.argmax(Y_pred1, axis=1)
y_true1=validation_generator2.classes

cm_first = confusion_matrix(y_true, y_pred)

cm_second = confusion_matrix(y_true1, y_pred1)

# Print the confusion matrices
print("Confusion Matrix for First Dataset:")
print(cm_first)

print("Confusion Matrix for Second Dataset:")
print(cm_second)
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 8s 527ms/step
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 182ms/step
# Confusion Matrix for First Dataset:
# [[ 4  5  5  4  6  7  9]
#  [ 3  8  3  6  9  3  8]
#  [10  6  6  5  4  8  1]
#  [ 7  6  5  6  7  3  6]
#  [ 4  3  4  9  6  7  7]
#  [ 4  3  5  6  7  7  8]
#  [ 4  8  6  8  4  4  6]]
# Confusion Matrix for Second Dataset:
# [[ 6  4  9  9  2  5  5]
#  [ 6  4  6  4  6  6  8]
#  [ 5  9  5  8  7  1  5]
#  [ 5  6  4  6  7  8  4]
#  [ 5  6  5  5  8  6  5]
#  [ 8  1  4  6  7  5  9]
#  [ 4  7  7  2  6  4 10]]

# %%
from keras import metrics

accuracy_male = metrics.Accuracy()
accuracy_female = metrics.Accuracy()
accuracy_male.update_state(y_true, y_pred)
accuracy_female.update_state(y_true1, y_pred1)

# Calculate the accuracy results
accuracy_result_male = accuracy_male.result().numpy()
accuracy_result_female = accuracy_female.result().numpy()

# Print the individual accuracies
print("Male Accuracy: %f" % accuracy_result_male)
print("Female Accuracy: %f" % accuracy_result_female)

# Calculate the accuracy difference
accuracy_difference = accuracy_result_male - accuracy_result_female
DP = accuracy_result_female/accuracy_result_male
# Print the accuracy difference
print("Accuracy Difference: %f" % accuracy_difference)
print("DP: %f" % DP)
# Out:
# Male Accuracy: 0.153571
# Female Accuracy: 0.157143
# Accuracy Difference: -0.003571
# DP: 1.023256
