# %%
import os

from platform import python_version
import warnings
import time
import datetime as dt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import multiprocessing as mp
import shutil

from imblearn.keras import BalancedBatchGenerator
from imblearn.under_sampling import RandomUnderSampler

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.densenet import DenseNet121, preprocess_input, decode_predictions
from tensorflow.keras.applications import ResNet50V2
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras import regularizers

import pandas as pd
import numpy as np
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go

from PIL import Image
import xml.etree.ElementTree as ET
import psutil
import random

warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
img_size = 96
epochs = 75
batch_size = 32
testsplit = .2
targetx = 96
targety = 96
learning_rate = 0.0001
classes = 7
seed = 23
print(seed)
# Out:
# 23

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from collections import Counter

model_name = 'RNMaleDominantmodel.keras'
# Define two different ImageDataGenerators with their respective directories
datagen1 = ImageDataGenerator(
        rescale=1./255,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        fill_mode='nearest',
        preprocessing_function=preprocess_input
)

datagen2 = ImageDataGenerator(
        rescale=1./255,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        fill_mode='nearest',
        preprocessing_function=preprocess_input
)

train_dir1 = 'KDEFMF/MaleDominantTraining'
train_dir2 = 'KDEFMF/FemaleNonDominantTraining'
val_dir1 = 'KDEFMF/MaleBalancedValidation'
val_dir2 = 'KDEFMF/FemaleBalancedValidation'

# Create two separate generators using different directories
train_generator1 = datagen1.flow_from_directory(
    train_dir1,
    target_size=(targetx,targety),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
    seed=seed
)
validation_generator1 = datagen1.flow_from_directory(
    val_dir1,
    target_size=(targetx,targety),
    batch_size=batch_size,
    class_mode='categorical',
)
validation_generator2 = datagen2.flow_from_directory(
    val_dir2,
    target_size=(targetx,targety),
    batch_size=batch_size,
    class_mode='categorical',
)

train_generator2 = datagen2.flow_from_directory(
    train_dir2,
    target_size=(targetx,targety),
    batch_size=batch_size,
    class_mode='categorical',
    shuffle=True,
    seed=seed
)

total_train_samples = len(train_generator1.filenames) + len(train_generator2.filenames)
total_validation_samples = len(validation_generator1.filenames) + len(validation_generator2.filenames)

# Combine labels from both generators
all_labels = list(train_generator1.classes) + list(train_generator2.classes)

# Get class indices (assuming they are the same for both generators)
class_indices = train_generator1.class_indices
index_to_class = {v: k for k, v in class_indices.items()}

# Count the number of occurrences of each class
class_counts = Counter(all_labels)

# Print the number of images per class
for class_index, count in class_counts.items():
    class_name = index_to_class[class_index]
    print(f"Class '{class_name}' has {count} images.")
    
def combined_generator(gen1, gen2, num_batches):
    while True:
        try:
            batch1_x, batch1_y = next(gen1)
            batch2_x, batch2_y = next(gen2)

            combined_x = np.concatenate((batch1_x, batch2_x), axis=0)
            combined_y = np.concatenate((batch1_y, batch2_y), axis=0)

            yield combined_x, combined_y
        except StopIteration as e:
            print("Generator exhausted or encountered an error:", e)
            break
# Out:
# Found 980 images belonging to 7 classes.
# Found 280 images belonging to 7 classes.
# Found 280 images belonging to 7 classes.
# Found 420 images belonging to 7 classes.
# Class 'angry' has 200 images.
# Class 'disgust' has 200 images.
# Class 'fear' has 200 images.
# Class 'happy' has 200 images.
# Class 'neutral' has 200 images.
# Class 'sad' has 200 images.
# Class 'surprise' has 200 images.

# %%
base_model = ResNet50V2(include_top=False, weights='imagenet', input_shape=(targetx, targety, 3))

# Custom Layers neccesarry to acheive high acurracy 
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Flatten() (x)
x = BatchNormalization()(x)
x=Dropout(0.3)(x)
x = Dense(512, activation='relu',  kernel_initializer=glorot_uniform(seed),kernel_regularizer=regularizers.L2(0.001),activity_regularizer=regularizers.L2(1e-4), bias_initializer='zeros')(x)
x = BatchNormalization()(x)
x=Dropout(0.3)(x)
x = Dense(256, activation='relu',  kernel_initializer=glorot_uniform(seed),kernel_regularizer=regularizers.L2(0.001),activity_regularizer=regularizers.L2(1e-4), bias_initializer='zeros')(x)
x = BatchNormalization()(x)
x=Dropout(0.3)(x)
x = Dense(128, activation='relu',  kernel_initializer=glorot_uniform(seed),kernel_regularizer=regularizers.L2(0.001),activity_regularizer=regularizers.L2(1e-4), bias_initializer='zeros')(x)
x = BatchNormalization()(x)
x=Dropout(0.3)(x)
predictions = Dense(classes, activation='softmax', kernel_initializer='random_uniform', bias_initializer='zeros')(x)

model = tf.keras.Model(inputs=base_model.input, outputs=predictions)
optimizer = Adam(learning_rate=learning_rate)
loss = "categorical_crossentropy"

for layer in model.layers:
    layer.trainable = True

model.compile(optimizer=optimizer,
              loss=loss,
              metrics=["accuracy"])

# %%
# Define the number of batches you want from each generator
num_batches_per_gen = 100  # Adjust as needed

# Use the combined generator for training
combined_train_generator = combined_generator(train_generator1, train_generator2, num_batches_per_gen)

# Use the combined generator for validation
combined_validation_generator = combined_generator(validation_generator1, validation_generator2, num_batches_per_gen)


steps_per_epoch = total_train_samples // (2 * 32)
validation_steps = total_validation_samples // (2 * 32)

# Ensure correct optimizer and loss function
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure ModelCheckpoint is correctly configured used for callback to save the best value based on val_accuracy
checkpoint = ModelCheckpoint(model_name, monitor='val_accuracy', save_best_only=True, verbose=1)

# Train the model with callbacks
history = model.fit(
    combined_train_generator,
    steps_per_epoch=steps_per_epoch,
    validation_data=combined_validation_generator,
    validation_steps=validation_steps,
    epochs=epochs,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 831ms/step - accuracy: 0.1525 - loss: 8.6069
# Epoch 1: val_accuracy improved from -inf to 0.14062, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 0.1524 - loss: 8.6001 - val_accuracy: 0.1406 - val_loss: 3.4735
# Epoch 2/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 797ms/step - accuracy: 0.1587 - loss: 8.0468
# Epoch 2: val_accuracy did not improve from 0.14062
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 19s 923ms/step - accuracy: 0.1589 - loss: 8.0380 - val_accuracy: 0.1351 - val_loss: 4.0782
# Epoch 3/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 842ms/step - accuracy: 0.1642 - loss: 7.3721
# Epoch 3: val_accuracy improved from 0.14062 to 0.14113, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1645 - loss: 7.3555 - val_accuracy: 0.1411 - val_loss: 4.1383
# Epoch 4/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 828ms/step - accuracy: 0.1582 - loss: 6.0606
# Epoch 4: val_accuracy did not improve from 0.14113
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 19s 921ms/step - accuracy: 0.1587 - loss: 6.0516 - val_accuracy: 0.1270 - val_loss: 4.2406
# Epoch 5/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 843ms/step - accuracy: 0.1643 - loss: 5.7290
# Epoch 5: val_accuracy improved from 0.14113 to 0.14516, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1643 - loss: 5.7247 - val_accuracy: 0.1452 - val_loss: 4.1749
# Epoch 6/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 818ms/step - accuracy: 0.1668 - loss: 5.5089
# Epoch 6: val_accuracy did not improve from 0.14516
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 19s 907ms/step - accuracy: 0.1668 - loss: 5.5060 - val_accuracy: 0.1351 - val_loss: 4.0592
# Epoch 7/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 911ms/step - accuracy: 0.1531 - loss: 5.4971
# Epoch 7: val_accuracy did not improve from 0.14516
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1533 - loss: 5.4937 - val_accuracy: 0.1391 - val_loss: 3.9284
# Epoch 8/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 879ms/step - accuracy: 0.1826 - loss: 5.2699
# Epoch 8: val_accuracy improved from 0.14516 to 0.15524, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 22s 1s/step - accuracy: 0.1824 - loss: 5.2691 - val_accuracy: 0.1552 - val_loss: 3.8792
# Epoch 9/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 923ms/step - accuracy: 0.1759 - loss: 5.4089
# Epoch 9: val_accuracy did not improve from 0.15524
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.1763 - loss: 5.4046 - val_accuracy: 0.1472 - val_loss: 3.8601
# Epoch 10/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 898ms/step - accuracy: 0.2100 - loss: 5.1536
# Epoch 10: val_accuracy did not improve from 0.15524
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 997ms/step - accuracy: 0.2101 - loss: 5.1513 - val_accuracy: 0.1465 - val_loss: 3.8369
# Epoch 11/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 909ms/step - accuracy: 0.2364 - loss: 5.0300
# Epoch 11: val_accuracy did not improve from 0.15524
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.2368 - loss: 5.0292 - val_accuracy: 0.1290 - val_loss: 3.7534
# Epoch 12/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 899ms/step - accuracy: 0.3062 - loss: 4.8469
# Epoch 12: val_accuracy improved from 0.15524 to 0.15726, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 23s 1s/step - accuracy: 0.3056 - loss: 4.8454 - val_accuracy: 0.1573 - val_loss: 3.6756
# Epoch 13/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 899ms/step - accuracy: 0.2665 - loss: 4.8926
# Epoch 13: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 994ms/step - accuracy: 0.2665 - loss: 4.8904 - val_accuracy: 0.1371 - val_loss: 3.6632
# Epoch 14/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 880ms/step - accuracy: 0.3110 - loss: 4.7128
# Epoch 14: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 977ms/step - accuracy: 0.3106 - loss: 4.7113 - val_accuracy: 0.1512 - val_loss: 3.6556
# Epoch 15/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 887ms/step - accuracy: 0.3273 - loss: 4.7341
# Epoch 15: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 983ms/step - accuracy: 0.3274 - loss: 4.7309 - val_accuracy: 0.1270 - val_loss: 3.5919
# Epoch 16/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 890ms/step - accuracy: 0.3166 - loss: 4.5352
# Epoch 16: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 988ms/step - accuracy: 0.3172 - loss: 4.5336 - val_accuracy: 0.1290 - val_loss: 3.6142
# Epoch 17/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 889ms/step - accuracy: 0.3926 - loss: 4.4156
# Epoch 17: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 979ms/step - accuracy: 0.3921 - loss: 4.4149 - val_accuracy: 0.1552 - val_loss: 3.6195
# Epoch 18/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 853ms/step - accuracy: 0.3740 - loss: 4.3547
# Epoch 18: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 957ms/step - accuracy: 0.3740 - loss: 4.3534 - val_accuracy: 0.1391 - val_loss: 3.6100
# Epoch 19/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 917ms/step - accuracy: 0.3912 - loss: 4.2791
# Epoch 19: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.3927 - loss: 4.2778 - val_accuracy: 0.1543 - val_loss: 3.7588
# Epoch 20/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 863ms/step - accuracy: 0.4116 - loss: 4.2001
# Epoch 20: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 967ms/step - accuracy: 0.4132 - loss: 4.1993 - val_accuracy: 0.1270 - val_loss: 3.9056
# Epoch 21/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 875ms/step - accuracy: 0.4744 - loss: 4.1465
# Epoch 21: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 20s 967ms/step - accuracy: 0.4752 - loss: 4.1451 - val_accuracy: 0.1472 - val_loss: 4.0694
# Epoch 22/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5109 - loss: 4.1076
# Epoch 22: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 25s 1s/step - accuracy: 0.5114 - loss: 4.1052 - val_accuracy: 0.1411 - val_loss: 4.1671
# Epoch 23/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5064 - loss: 4.0100
# Epoch 23: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.5075 - loss: 4.0083 - val_accuracy: 0.1391 - val_loss: 3.9921
# Epoch 24/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5557 - loss: 3.9233
# Epoch 24: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.5547 - loss: 3.9232 - val_accuracy: 0.1351 - val_loss: 224.2589
# Epoch 25/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 902ms/step - accuracy: 0.5743 - loss: 3.8930
# Epoch 25: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 21s 1s/step - accuracy: 0.5740 - loss: 3.8921 - val_accuracy: 0.1310 - val_loss: 1578.2522
# Epoch 26/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5705 - loss: 3.8001
# Epoch 26: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.5710 - loss: 3.7984 - val_accuracy: 0.1250 - val_loss: 225.9167
# Epoch 27/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5996 - loss: 3.7470
# Epoch 27: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.5998 - loss: 3.7440 - val_accuracy: 0.1431 - val_loss: 107.5906
# Epoch 28/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6332 - loss: 3.5844
# Epoch 28: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.6330 - loss: 3.5838 - val_accuracy: 0.1133 - val_loss: 35.2874
# Epoch 29/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6122 - loss: 3.6077
# Epoch 29: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.6122 - loss: 3.6063 - val_accuracy: 0.1391 - val_loss: 4.8180
# Epoch 30/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6232 - loss: 3.5087
# Epoch 30: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 26s 1s/step - accuracy: 0.6232 - loss: 3.5086 - val_accuracy: 0.1472 - val_loss: 3.3785
# Epoch 31/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6473 - loss: 3.5036
# Epoch 31: val_accuracy did not improve from 0.15726
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 31s 1s/step - accuracy: 0.6467 - loss: 3.5033 - val_accuracy: 0.1472 - val_loss: 3.3529
# Epoch 32/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6505 - loss: 3.4308
# Epoch 32: val_accuracy improved from 0.15726 to 0.18347, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 34s 2s/step - accuracy: 0.6507 - loss: 3.4309 - val_accuracy: 0.1835 - val_loss: 3.3150
# Epoch 33/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6638 - loss: 3.4153
# Epoch 33: val_accuracy did not improve from 0.18347
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 30s 1s/step - accuracy: 0.6634 - loss: 3.4149 - val_accuracy: 0.1673 - val_loss: 3.2972
# Epoch 34/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6941 - loss: 3.2787
# Epoch 34: val_accuracy did not improve from 0.18347
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 29s 1s/step - accuracy: 0.6926 - loss: 3.2802 - val_accuracy: 0.1794 - val_loss: 3.3315
# Epoch 35/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.6831 - loss: 3.3393
# Epoch 35: val_accuracy improved from 0.18347 to 0.22177, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 31s 2s/step - accuracy: 0.6833 - loss: 3.3371 - val_accuracy: 0.2218 - val_loss: 3.3829
# Epoch 36/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7017 - loss: 3.2817
# Epoch 36: val_accuracy improved from 0.22177 to 0.23992, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.7015 - loss: 3.2790 - val_accuracy: 0.2399 - val_loss: 3.4187
# Epoch 37/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7195 - loss: 3.1261
# Epoch 37: val_accuracy improved from 0.23992 to 0.26367, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 32s 2s/step - accuracy: 0.7195 - loss: 3.1253 - val_accuracy: 0.2637 - val_loss: 3.3588
# Epoch 38/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7538 - loss: 3.1539
# Epoch 38: val_accuracy improved from 0.26367 to 0.29839, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 33s 2s/step - accuracy: 0.7525 - loss: 3.1533 - val_accuracy: 0.2984 - val_loss: 3.1947
# Epoch 39/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7178 - loss: 3.0779
# Epoch 39: val_accuracy improved from 0.29839 to 0.35081, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.7178 - loss: 3.0768 - val_accuracy: 0.3508 - val_loss: 3.1120
# Epoch 40/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7707 - loss: 2.9707
# Epoch 40: val_accuracy improved from 0.35081 to 0.43145, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.7698 - loss: 2.9704 - val_accuracy: 0.4315 - val_loss: 2.9187
# Epoch 41/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7509 - loss: 2.9931
# Epoch 41: val_accuracy improved from 0.43145 to 0.50403, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.7513 - loss: 2.9919 - val_accuracy: 0.5040 - val_loss: 2.7044
# Epoch 42/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7410 - loss: 2.9935
# Epoch 42: val_accuracy did not improve from 0.50403
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 38s 2s/step - accuracy: 0.7395 - loss: 2.9935 - val_accuracy: 0.3911 - val_loss: 2.8152
# Epoch 43/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6438 - loss: 3.0651
# Epoch 43: val_accuracy did not improve from 0.50403
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 39s 2s/step - accuracy: 0.6437 - loss: 3.0652 - val_accuracy: 0.3448 - val_loss: 4.5517
# Epoch 44/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.6415 - loss: 3.0641
# Epoch 44: val_accuracy did not improve from 0.50403
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.6428 - loss: 3.0607 - val_accuracy: 0.4859 - val_loss: 2.6738
# Epoch 45/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7339 - loss: 2.8842
# Epoch 45: val_accuracy improved from 0.50403 to 0.55040, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.7337 - loss: 2.8824 - val_accuracy: 0.5504 - val_loss: 2.5948
# Epoch 46/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7436 - loss: 2.8166
# Epoch 46: val_accuracy improved from 0.55040 to 0.68750, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 53s 3s/step - accuracy: 0.7437 - loss: 2.8141 - val_accuracy: 0.6875 - val_loss: 2.3313
# Epoch 47/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7864 - loss: 2.7734
# Epoch 47: val_accuracy improved from 0.68750 to 0.76210, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.7859 - loss: 2.7737 - val_accuracy: 0.7621 - val_loss: 2.2063
# Epoch 48/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7886 - loss: 2.6957
# Epoch 48: val_accuracy improved from 0.76210 to 0.78629, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 49s 2s/step - accuracy: 0.7887 - loss: 2.6940 - val_accuracy: 0.7863 - val_loss: 2.7076
# Epoch 49/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7701 - loss: 2.6944
# Epoch 49: val_accuracy did not improve from 0.78629
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.7708 - loss: 2.6928 - val_accuracy: 0.7621 - val_loss: 3.7742
# Epoch 50/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8089 - loss: 2.5849
# Epoch 50: val_accuracy improved from 0.78629 to 0.85484, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.8089 - loss: 2.5843 - val_accuracy: 0.8548 - val_loss: 2.0393
# Epoch 51/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8339 - loss: 2.5335
# Epoch 51: val_accuracy did not improve from 0.85484
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8335 - loss: 2.5337 - val_accuracy: 0.8266 - val_loss: 2.0304
# Epoch 52/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8186 - loss: 2.5210
# Epoch 52: val_accuracy did not improve from 0.85484
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8186 - loss: 2.5203 - val_accuracy: 0.8448 - val_loss: 1.9619
# Epoch 53/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8361 - loss: 2.4299
# Epoch 53: val_accuracy improved from 0.85484 to 0.89315, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 51s 2s/step - accuracy: 0.8368 - loss: 2.4288 - val_accuracy: 0.8931 - val_loss: 3.3726
# Epoch 54/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8261 - loss: 2.4102
# Epoch 54: val_accuracy did not improve from 0.89315
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8264 - loss: 2.4097 - val_accuracy: 0.8528 - val_loss: 8.1678
# Epoch 55/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8554 - loss: 2.4436
# Epoch 55: val_accuracy did not improve from 0.89315
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.8562 - loss: 2.4408 - val_accuracy: 0.8789 - val_loss: 15.8331
# Epoch 56/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8826 - loss: 2.3298
# Epoch 56: val_accuracy improved from 0.89315 to 0.93145, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.8825 - loss: 2.3292 - val_accuracy: 0.9315 - val_loss: 3.9481
# Epoch 57/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8956 - loss: 2.2534
# Epoch 57: val_accuracy improved from 0.93145 to 0.94556, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.8950 - loss: 2.2538 - val_accuracy: 0.9456 - val_loss: 1.7289
# Epoch 58/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8566 - loss: 2.3098
# Epoch 58: val_accuracy did not improve from 0.94556
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 45s 2s/step - accuracy: 0.8563 - loss: 2.3101 - val_accuracy: 0.9194 - val_loss: 1.7227
# Epoch 59/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8675 - loss: 2.2837
# Epoch 59: val_accuracy did not improve from 0.94556
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 46s 2s/step - accuracy: 0.8682 - loss: 2.2812 - val_accuracy: 0.9274 - val_loss: 1.7979
# Epoch 60/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8586 - loss: 2.2648
# Epoch 60: val_accuracy did not improve from 0.94556
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8587 - loss: 2.2643 - val_accuracy: 0.9052 - val_loss: 1.8257
# Epoch 61/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8734 - loss: 2.1956
# Epoch 61: val_accuracy improved from 0.94556 to 0.94960, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 52s 3s/step - accuracy: 0.8736 - loss: 2.1953 - val_accuracy: 0.9496 - val_loss: 1.9279
# Epoch 62/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8872 - loss: 2.1002
# Epoch 62: val_accuracy improved from 0.94960 to 0.97177, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 50s 2s/step - accuracy: 0.8874 - loss: 2.1007 - val_accuracy: 0.9718 - val_loss: 1.8588
# Epoch 63/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9048 - loss: 2.1314
# Epoch 63: val_accuracy did not improve from 0.97177
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9048 - loss: 2.1317 - val_accuracy: 0.7984 - val_loss: 5.0444
# Epoch 64/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8838 - loss: 2.1107
# Epoch 64: val_accuracy did not improve from 0.97177
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 43s 2s/step - accuracy: 0.8846 - loss: 2.1098 - val_accuracy: 0.8438 - val_loss: 13.0590
# Epoch 65/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9196 - loss: 2.0383
# Epoch 65: val_accuracy did not improve from 0.97177
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9197 - loss: 2.0366 - val_accuracy: 0.9577 - val_loss: 2.8134
# Epoch 66/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9308 - loss: 2.0093
# Epoch 66: val_accuracy did not improve from 0.97177
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9308 - loss: 2.0094 - val_accuracy: 0.9153 - val_loss: 2.5301
# Epoch 67/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9426 - loss: 1.9458
# Epoch 67: val_accuracy did not improve from 0.97177
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 44s 2s/step - accuracy: 0.9425 - loss: 1.9460 - val_accuracy: 0.9698 - val_loss: 1.5296
# Epoch 68/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9292 - loss: 1.9530
# Epoch 68: val_accuracy improved from 0.97177 to 0.98387, saving model to RNMaleDominantmodel.keras
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 48s 2s/step - accuracy: 0.9291 - loss: 1.9523 - val_accuracy: 0.9839 - val_loss: 1.4520
# Epoch 69/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9436 - loss: 1.9295
# Epoch 69: val_accuracy did not improve from 0.98387
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.9432 - loss: 1.9288 - val_accuracy: 0.9375 - val_loss: 1.5053
# Epoch 70/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9324 - loss: 1.9136
# Epoch 70: val_accuracy did not improve from 0.98387
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.9314 - loss: 1.9153 - val_accuracy: 0.6875 - val_loss: 2.0502
# Epoch 71/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8622 - loss: 2.0779
# Epoch 71: val_accuracy did not improve from 0.98387
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 42s 2s/step - accuracy: 0.8614 - loss: 2.0788 - val_accuracy: 0.8065 - val_loss: 1.8095
# Epoch 72/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8444 - loss: 2.0951
# Epoch 72: val_accuracy did not improve from 0.98387
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8445 - loss: 2.0949 - val_accuracy: 0.7843 - val_loss: 1.9203
# Epoch 73/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8458 - loss: 2.0530
# Epoch 73: val_accuracy did not improve from 0.98387
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8468 - loss: 2.0508 - val_accuracy: 0.8926 - val_loss: 1.6586
# Epoch 74/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.8942 - loss: 1.9941
# Epoch 74: val_accuracy did not improve from 0.98387
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 41s 2s/step - accuracy: 0.8942 - loss: 1.9945 - val_accuracy: 0.8367 - val_loss: 2.9583
# Epoch 75/75
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9032 - loss: 1.9157
# Epoch 75: val_accuracy did not improve from 0.98387
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 40s 2s/step - accuracy: 0.9033 - loss: 1.9157 - val_accuracy: 0.9093 - val_loss: 8.5645

# %%
model = tf.keras.models.load_model(model_name)

# %%
# Define the number of batches you want from each generator
num_batches_per_gen = 100  # Adjust as needed

# Use the combined generator for training
combined_train_generator = combined_generator(train_generator1, train_generator2, num_batches_per_gen)

# Use the combined generator for validation
combined_validation_generator = combined_generator(validation_generator1, validation_generator2, num_batches_per_gen)


steps_per_epoch = total_train_samples // (2 * 32)
validation_steps = total_validation_samples // (2 * 32)

# %%
# Collect predictions and true labels
y_true = []
y_pred = []

for batch_x, batch_y in combined_validation_generator:
    # Make predictions
    predictions = model.predict(batch_x)
    predicted_classes = np.argmax(predictions, axis=1)
    true_classes = np.argmax(batch_y, axis=1)
    
    # Append to lists
    y_true.extend(true_classes)
    y_pred.extend(predicted_classes)
    
    # Stop if you have processed the entire validation set
    if len(y_true) >= total_validation_samples:
        break

# Generate classification report
report = classification_report(y_true, y_pred, target_names=validation_generator1.class_indices.keys())
print(report)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 22s 284ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 271ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 370ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 251ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 241ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 287ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 319ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 10s 10s/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 1s 412ms/step
#               precision    recall  f1-score   support
#
#        angry       1.00      0.98      0.99        83
#      disgust       1.00      0.99      0.99        80
#         fear       0.95      0.94      0.95        83
#        happy       0.96      0.96      0.96        76
#      neutral       0.95      1.00      0.97        77
#          sad       0.98      0.98      0.98        81
#     surprise       0.99      0.99      0.99        80
#
#     accuracy                           0.97       560
#    macro avg       0.98      0.98      0.97       560
# weighted avg       0.98      0.97      0.98       560

# %%
import numpy as np
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import classification_report

# Assuming you have the model and validation generators defined
# validation_generator1 and validation_generator2
# Also assuming the target_names are the same for both generators

# Function to generate and print classification report
def generate_classification_report(generator, generator_name):
    y_true = []
    y_pred = []

    for batch_x, batch_y in generator:
        # Generate predictions
        predictions = model.predict(batch_x)
        predicted_classes = np.argmax(predictions, axis=1)
        true_classes = np.argmax(batch_y, axis=1)

        # Collect predictions and true labels
        y_true.extend(true_classes)
        y_pred.extend(predicted_classes)

        # Break if processed all samples
        if len(y_true) >= generator.samples:
            break

    # Generate and print the classification report
    target_names = list(generator.class_indices.keys())
    report = classification_report(y_true, y_pred, target_names=target_names)
    print(f"Classification Report for {generator_name}:\n{report}")

# Generate and print classification reports for both validation generators
generate_classification_report(validation_generator1, "Validation Generator 1")
generate_classification_report(validation_generator2, "Validation Generator 2")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 517ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 269ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 465ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 496ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 584ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 430ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 381ms/step
# Classification Report for Validation Generator 1:
#               precision    recall  f1-score   support
#
#        angry       1.00      1.00      1.00        39
#      disgust       1.00      0.95      0.97        41
#         fear       0.95      0.93      0.94        41
#        happy       0.97      0.97      0.97        40
#      neutral       0.95      1.00      0.98        40
#          sad       0.95      0.95      0.95        38
#     surprise       0.95      0.98      0.96        41
#
#     accuracy                           0.97       280
#    macro avg       0.97      0.97      0.97       280
# weighted avg       0.97      0.97      0.97       280
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 451ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 661ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 615ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 492ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 554ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# Classification Report for Validation Generator 2:
#               precision    recall  f1-score   support
#
#        angry       1.00      1.00      1.00        36
#      disgust       1.00      1.00      1.00        40
#         fear       0.95      0.93      0.94        43
#        happy       0.98      1.00      0.99        40
#      neutral       1.00      1.00      1.00        40
#          sad       1.00      1.00      1.00        41
#     surprise       0.95      0.95      0.95        40
#
#     accuracy                           0.98       280
#    macro avg       0.98      0.98      0.98       280
# weighted avg       0.98      0.98      0.98       280

# %%
print(model_name)
# Out:
# RNMaleDominantmodel.keras

# %%
import numpy as np

def balanced_combination_generator(validation_generator1, validation_generator2, batch_size):
    class_indices = validation_generator1.class_indices
    num_classes = len(class_indices)

    while True:
        # Collect images and labels for a batch
        combined_images = []
        combined_labels = []

        # Determine how many samples to draw from each generator
        half_batch_size = batch_size // 2

        # Draw half batch from each generator
        for _ in range(half_batch_size):
            images1, labels1 = next(validation_generator1)
            images2, labels2 = next(validation_generator2)

            # Add to combined list
            combined_images.append(images1)
            combined_labels.append(labels1)
            combined_images.append(images2)
            combined_labels.append(labels2)

        # Concatenate all gathered images and labels
        combined_images = np.concatenate(combined_images, axis=0)
        combined_labels = np.concatenate(combined_labels, axis=0)

        # Shuffle the combined batch
        indices = np.arange(combined_images.shape[0])
        np.random.shuffle(indices)

        combined_images = combined_images[indices]
        combined_labels = combined_labels[indices]

        yield combined_images, combined_labels

# Use the custom generator in model evaluation
batch_size = 32
combined_validation_generator = balanced_combination_generator(
    validation_generator1, validation_generator2, batch_size=batch_size
)

# Evaluate the model using the combined validation generator
model.evaluate(combined_validation_generator, steps=validation_steps)
# Out:
# 1/8 ━━━━━━━━━━━━━━━━━━━━ 3:57 34s/step - accuracy: 0.9732 - loss: 1.2864
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 46
#      41 combined_validation_generator = balanced_combination_generator(
#      42     validation_generator1, validation_generator2, batch_size=batch_size
#      43 )
#      45 # Evaluate the model using the combined validation generator
# ---> 46 model.evaluate(combined_validation_generator, steps=validation_steps)
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:118, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     116 filtered_tb = None
#     117 try:
# --> 118     return fn(*args, **kwargs)
#     119 except Exception as e:
#     120     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:435, in TensorFlowTrainer.evaluate(self, x, y, batch_size, verbose, sample_weight, steps, callbacks, return_dict, **kwargs)
#     433 for step, iterator in epoch_iterator.enumerate_epoch():
#     434     callbacks.on_test_batch_begin(step)
# --> 435     logs = self.test_function(iterator)
#     436     callbacks.on_test_batch_end(step, self._pythonify_logs(logs))
#     437     if self.stop_evaluating:
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:869, in Function._call(self, *args, **kwds)
#     866   self._lock.release()
#     867   # In this case we have created variables on the first call, so we run the
#     868   # defunned version which is guaranteed to never create variables.
# --> 869   return tracing_compilation.call_function(
#     870       args, kwds, self._no_variable_creation_config
#     871   )
#     872 elif self._variable_creation_config is not None:
#     873   # Release the lock early so that multiple threads can perform the call
#     874   # in parallel.
#     875   self._lock.release()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\tracing_compilation.py:139, in call_function(args, kwargs, tracing_options)
#     137 bound_args = function.function_type.bind(*args, **kwargs)
#     138 flat_inputs = function.function_type.unpack_inputs(bound_args)
# --> 139 return function._call_flat(  # pylint: disable=protected-access
#     140     flat_inputs, captured_inputs=function.captured_inputs
#     141 )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\context.py:1500, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1498 cancellation_context = cancellation.context()
#    1499 if cancellation_context is None:
# -> 1500   outputs = execute.execute(
#    1501       name.decode("utf-8"),
#    1502       num_outputs=num_outputs,
#    1503       inputs=tensor_inputs,
#    1504       attrs=attrs,
#    1505       ctx=self,
#    1506   )
#    1507 else:
#    1508   outputs = execute.execute_with_cancellation(
#    1509       name.decode("utf-8"),
#    1510       num_outputs=num_outputs,
#    (...)
#    1514       cancellation_manager=cancellation_context,
#    1515   )
#
# File ~\anaconda3\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
combined_validation_generator_samples = combined_validation_generator.samples
