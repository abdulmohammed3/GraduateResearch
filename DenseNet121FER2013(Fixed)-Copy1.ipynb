# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, BatchNormalization, Dropout, Input
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import regularizers
from tensorflow.keras.applications.densenet import DenseNet121, preprocess_input, decode_predictions
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('fer2013.csv')

# Preprocess the data
def preprocess_data(data):
    # Convert the pixels column to numpy arrays
    data['pixels'] = data['pixels'].apply(lambda x: np.array(x.split(), dtype='float32'))
    # Normalize the pixel values
    data['pixels'] = data['pixels'].apply(lambda x: x / 255.0)
    # Reshape the pixel values to 48x48
    data['pixels'] = data['pixels'].apply(lambda x: x.reshape(48, 48, 1))
    return data

data = preprocess_data(data)

# Split the data into training and validation sets
train_data = data[data['Usage'] == 'Training']
val_data = data[data['Usage'] == 'PublicTest']

# Extract features and labels
X_train = np.stack(train_data['pixels'].values)
y_train = tf.keras.utils.to_categorical(train_data['emotion'], num_classes=7)

X_val = np.stack(val_data['pixels'].values)
y_val = tf.keras.utils.to_categorical(val_data['emotion'], num_classes=7)

# Resize images to 96x96 to match EfficientNetB0 input size
X_train = tf.image.resize(X_train, [96, 96])
X_val = tf.image.resize(X_val, [96, 96])

# Convert grayscale images to RGB by duplicating the single channel three times
X_train = tf.image.grayscale_to_rgb(X_train)
X_val = tf.image.grayscale_to_rgb(X_val)

# %%
# Define the number of classes
num_classes = 7  # Update this to match your dataset
base_model = DenseNet121(include_top=False, weights='imagenet', input_shape=(96,96, 3))


# Modify the model to match the number of classes
x = base_model.output
x = GlobalAveragePooling2D()(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(512, activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(0.01))(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(256, activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(0.01))(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
x = Dense(128, activation='relu', kernel_initializer='glorot_uniform', kernel_regularizer=regularizers.l2(0.01))(x)
x = BatchNormalization()(x)
x = Dropout(0.3)(x)
predictions = Dense(num_classes, activation='softmax', kernel_initializer='random_uniform')(x)

model = Model(inputs=base_model.input, outputs=predictions)

# Compile the model
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Define the checkpoint callback
checkpoint = ModelCheckpoint('DNFer2013.keras', monitor='val_accuracy', save_best_only=True, verbose=1)

# Train the model
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=75,
    batch_size=64,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2598 - loss: 11.8850
# Epoch 1: val_accuracy improved from -inf to 0.51156, saving model to DNFer2013.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 566s 1s/step - accuracy: 0.2600 - loss: 11.8811 - val_accuracy: 0.5116 - val_loss: 7.3977
# Epoch 2/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.5609 - loss: 6.4770
# Epoch 2: val_accuracy improved from 0.51156 to 0.59181, saving model to DNFer2013.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 470s 1s/step - accuracy: 0.5609 - loss: 6.4754 - val_accuracy: 0.5918 - val_loss: 4.5492
# Epoch 3/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 987ms/step - accuracy: 0.6474 - loss: 3.9863
# Epoch 3: val_accuracy improved from 0.59181 to 0.60295, saving model to DNFer2013.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 459s 1s/step - accuracy: 0.6474 - loss: 3.9855 - val_accuracy: 0.6030 - val_loss: 3.0764
# Epoch 4/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 998ms/step - accuracy: 0.7105 - loss: 2.5835
# Epoch 4: val_accuracy improved from 0.60295 to 0.63249, saving model to DNFer2013.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 464s 1s/step - accuracy: 0.7105 - loss: 2.5831 - val_accuracy: 0.6325 - val_loss: 2.2164
# Epoch 5/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.7766 - loss: 1.7344
# Epoch 5: val_accuracy did not improve from 0.63249
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 470s 1s/step - accuracy: 0.7765 - loss: 1.7342 - val_accuracy: 0.6063 - val_loss: 1.9006
# Epoch 6/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8272 - loss: 1.2127
# Epoch 6: val_accuracy did not improve from 0.63249
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 476s 1s/step - accuracy: 0.8272 - loss: 1.2126 - val_accuracy: 0.6205 - val_loss: 1.6964
# Epoch 7/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8748 - loss: 0.8513
# Epoch 7: val_accuracy did not improve from 0.63249
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 483s 1s/step - accuracy: 0.8748 - loss: 0.8513 - val_accuracy: 0.6016 - val_loss: 1.6638
# Epoch 8/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.8980 - loss: 0.6398
# Epoch 8: val_accuracy did not improve from 0.63249
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 497s 1s/step - accuracy: 0.8980 - loss: 0.6398 - val_accuracy: 0.6074 - val_loss: 1.6875
# Epoch 9/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9187 - loss: 0.4880
# Epoch 9: val_accuracy improved from 0.63249 to 0.63555, saving model to DNFer2013.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 502s 1s/step - accuracy: 0.9187 - loss: 0.4880 - val_accuracy: 0.6356 - val_loss: 1.5540
# Epoch 10/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9312 - loss: 0.3893
# Epoch 10: val_accuracy did not improve from 0.63555
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 615s 1s/step - accuracy: 0.9312 - loss: 0.3893 - val_accuracy: 0.6119 - val_loss: 1.5236
# Epoch 11/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9409 - loss: 0.3184
# Epoch 11: val_accuracy improved from 0.63555 to 0.64335, saving model to DNFer2013.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 700s 2s/step - accuracy: 0.9409 - loss: 0.3184 - val_accuracy: 0.6434 - val_loss: 1.5569
# Epoch 12/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9503 - loss: 0.2632
# Epoch 12: val_accuracy did not improve from 0.64335
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 766s 2s/step - accuracy: 0.9502 - loss: 0.2632 - val_accuracy: 0.6403 - val_loss: 1.6161
# Epoch 13/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9520 - loss: 0.2411
# Epoch 13: val_accuracy did not improve from 0.64335
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 761s 2s/step - accuracy: 0.9520 - loss: 0.2411 - val_accuracy: 0.6403 - val_loss: 1.6046
# Epoch 14/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9535 - loss: 0.2222
# Epoch 14: val_accuracy did not improve from 0.64335
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 752s 2s/step - accuracy: 0.9535 - loss: 0.2223 - val_accuracy: 0.6322 - val_loss: 1.6858
# Epoch 15/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9577 - loss: 0.2037
# Epoch 15: val_accuracy did not improve from 0.64335
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 741s 2s/step - accuracy: 0.9576 - loss: 0.2037 - val_accuracy: 0.6211 - val_loss: 1.6268
# Epoch 16/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9644 - loss: 0.1704
# Epoch 16: val_accuracy did not improve from 0.64335
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 729s 2s/step - accuracy: 0.9644 - loss: 0.1704 - val_accuracy: 0.6383 - val_loss: 1.6331
# Epoch 17/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9615 - loss: 0.1789
# Epoch 17: val_accuracy improved from 0.64335 to 0.64976, saving model to DNFer2013.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 703s 2s/step - accuracy: 0.9615 - loss: 0.1789 - val_accuracy: 0.6498 - val_loss: 1.5705
# Epoch 18/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9665 - loss: 0.1624
# Epoch 18: val_accuracy did not improve from 0.64976
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 667s 1s/step - accuracy: 0.9665 - loss: 0.1624 - val_accuracy: 0.6225 - val_loss: 1.6962
# Epoch 19/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9628 - loss: 0.1730
# Epoch 19: val_accuracy did not improve from 0.64976
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 656s 1s/step - accuracy: 0.9628 - loss: 0.1730 - val_accuracy: 0.6336 - val_loss: 1.7181
# Epoch 20/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9670 - loss: 0.1473
# Epoch 20: val_accuracy did not improve from 0.64976
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 661s 1s/step - accuracy: 0.9670 - loss: 0.1473 - val_accuracy: 0.5940 - val_loss: 1.9187
# Epoch 21/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9672 - loss: 0.1485
# Epoch 21: val_accuracy did not improve from 0.64976
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 667s 1s/step - accuracy: 0.9672 - loss: 0.1485 - val_accuracy: 0.6459 - val_loss: 1.6559
# Epoch 22/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9717 - loss: 0.1350
# Epoch 22: val_accuracy did not improve from 0.64976
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 687s 2s/step - accuracy: 0.9717 - loss: 0.1350 - val_accuracy: 0.6383 - val_loss: 1.8695
# Epoch 23/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.9675 - loss: 0.1395
# Epoch 23: val_accuracy did not improve from 0.64976
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 695s 2s/step - accuracy: 0.9675 - loss: 0.1395 - val_accuracy: 0.6464 - val_loss: 1.7159
# Epoch 24/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9739 - loss: 0.1213
# Epoch 24: val_accuracy did not improve from 0.64976
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 711s 2s/step - accuracy: 0.9739 - loss: 0.1213 - val_accuracy: 0.6481 - val_loss: 1.6170
# Epoch 25/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9739 - loss: 0.1226
# Epoch 25: val_accuracy did not improve from 0.64976
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 705s 2s/step - accuracy: 0.9739 - loss: 0.1226 - val_accuracy: 0.6241 - val_loss: 1.8899
# Epoch 26/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9709 - loss: 0.1316
# Epoch 26: val_accuracy improved from 0.64976 to 0.65478, saving model to DNFer2013.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 712s 2s/step - accuracy: 0.9709 - loss: 0.1316 - val_accuracy: 0.6548 - val_loss: 1.7697
# Epoch 27/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9780 - loss: 0.1117
# Epoch 27: val_accuracy did not improve from 0.65478
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 712s 2s/step - accuracy: 0.9780 - loss: 0.1117 - val_accuracy: 0.6367 - val_loss: 1.8954
# Epoch 28/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9718 - loss: 0.1284
# Epoch 28: val_accuracy did not improve from 0.65478
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 718s 2s/step - accuracy: 0.9718 - loss: 0.1284 - val_accuracy: 0.6542 - val_loss: 1.7557
# Epoch 29/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9753 - loss: 0.1171
# Epoch 29: val_accuracy did not improve from 0.65478
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 747s 2s/step - accuracy: 0.9753 - loss: 0.1172 - val_accuracy: 0.6247 - val_loss: 1.9332
# Epoch 30/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9751 - loss: 0.1210
# Epoch 30: val_accuracy did not improve from 0.65478
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 769s 2s/step - accuracy: 0.9751 - loss: 0.1210 - val_accuracy: 0.6456 - val_loss: 1.6921
# Epoch 31/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9774 - loss: 0.1117
# Epoch 31: val_accuracy did not improve from 0.65478
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 776s 2s/step - accuracy: 0.9774 - loss: 0.1117 - val_accuracy: 0.6428 - val_loss: 1.8874
# Epoch 32/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9723 - loss: 0.1210
# Epoch 32: val_accuracy did not improve from 0.65478
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 752s 2s/step - accuracy: 0.9723 - loss: 0.1211 - val_accuracy: 0.6475 - val_loss: 1.6493
# Epoch 33/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9765 - loss: 0.1132
# Epoch 33: val_accuracy did not improve from 0.65478
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 741s 2s/step - accuracy: 0.9765 - loss: 0.1132 - val_accuracy: 0.6539 - val_loss: 1.7698
# Epoch 34/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9772 - loss: 0.1094
# Epoch 34: val_accuracy did not improve from 0.65478
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 747s 2s/step - accuracy: 0.9772 - loss: 0.1094 - val_accuracy: 0.6456 - val_loss: 1.8047
# Epoch 35/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9827 - loss: 0.0909
# Epoch 35: val_accuracy did not improve from 0.65478
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 750s 2s/step - accuracy: 0.9827 - loss: 0.0909 - val_accuracy: 0.6328 - val_loss: 1.8640
# Epoch 36/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9740 - loss: 0.1178
# Epoch 36: val_accuracy improved from 0.65478 to 0.65534, saving model to DNFer2013.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 752s 2s/step - accuracy: 0.9740 - loss: 0.1178 - val_accuracy: 0.6553 - val_loss: 1.6741
# Epoch 37/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9789 - loss: 0.1043
# Epoch 37: val_accuracy did not improve from 0.65534
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 750s 2s/step - accuracy: 0.9789 - loss: 0.1043 - val_accuracy: 0.6512 - val_loss: 1.8912
# Epoch 38/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9807 - loss: 0.0981
# Epoch 38: val_accuracy did not improve from 0.65534
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 752s 2s/step - accuracy: 0.9807 - loss: 0.0981 - val_accuracy: 0.6503 - val_loss: 1.8653
# Epoch 39/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9771 - loss: 0.1088
# Epoch 39: val_accuracy improved from 0.65534 to 0.67010, saving model to DNFer2013.keras
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 757s 2s/step - accuracy: 0.9771 - loss: 0.1088 - val_accuracy: 0.6701 - val_loss: 1.7244
# Epoch 40/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9795 - loss: 0.1002
# Epoch 40: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 760s 2s/step - accuracy: 0.9795 - loss: 0.1002 - val_accuracy: 0.6411 - val_loss: 1.9400
# Epoch 41/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9787 - loss: 0.1025
# Epoch 41: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 763s 2s/step - accuracy: 0.9787 - loss: 0.1025 - val_accuracy: 0.6537 - val_loss: 1.7125
# Epoch 42/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9806 - loss: 0.0934
# Epoch 42: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 766s 2s/step - accuracy: 0.9806 - loss: 0.0934 - val_accuracy: 0.6548 - val_loss: 1.7034
# Epoch 43/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9800 - loss: 0.0983
# Epoch 43: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━
75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9853 - loss: 0.0816
# Epoch 62: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1389s 3s/step - accuracy: 0.9853 - loss: 0.0816 - val_accuracy: 0.6344 - val_loss: 1.9855
# Epoch 63/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9823 - loss: 0.0858
# Epoch 63: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1386s 3s/step - accuracy: 0.9823 - loss: 0.0858 - val_accuracy: 0.6592 - val_loss: 1.8138
# Epoch 64/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9831 - loss: 0.0845
# Epoch 64: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1389s 3s/step - accuracy: 0.9831 - loss: 0.0845 - val_accuracy: 0.6447 - val_loss: 2.1083
# Epoch 65/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9876 - loss: 0.0681
# Epoch 65: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1374s 3s/step - accuracy: 0.9876 - loss: 0.0681 - val_accuracy: 0.6682 - val_loss: 1.9661
# Epoch 66/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9858 - loss: 0.0755
# Epoch 66: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1371s 3s/step - accuracy: 0.9858 - loss: 0.0755 - val_accuracy: 0.6255 - val_loss: 2.1196
# Epoch 67/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9839 - loss: 0.0814
# Epoch 67: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1341s 3s/step - accuracy: 0.9839 - loss: 0.0814 - val_accuracy: 0.6542 - val_loss: 1.8675
# Epoch 68/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9850 - loss: 0.0784
# Epoch 68: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1339s 3s/step - accuracy: 0.9850 - loss: 0.0784 - val_accuracy: 0.6531 - val_loss: 2.0430
# Epoch 69/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9855 - loss: 0.0741
# Epoch 69: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1365s 3s/step - accuracy: 0.9855 - loss: 0.0741 - val_accuracy: 0.6676 - val_loss: 1.7599
# Epoch 70/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9876 - loss: 0.0691
# Epoch 70: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1370s 3s/step - accuracy: 0.9876 - loss: 0.0691 - val_accuracy: 0.6631 - val_loss: 1.8129
# Epoch 71/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9853 - loss: 0.0744
# Epoch 71: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1392s 3s/step - accuracy: 0.9853 - loss: 0.0744 - val_accuracy: 0.6601 - val_loss: 2.0113
# Epoch 72/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9817 - loss: 0.0895
# Epoch 72: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1393s 3s/step - accuracy: 0.9817 - loss: 0.0895 - val_accuracy: 0.6659 - val_loss: 1.7872
# Epoch 73/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9864 - loss: 0.0720
# Epoch 73: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1412s 3s/step - accuracy: 0.9864 - loss: 0.0720 - val_accuracy: 0.6592 - val_loss: 1.8057
# Epoch 74/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9875 - loss: 0.0660
# Epoch 74: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1394s 3s/step - accuracy: 0.9875 - loss: 0.0660 - val_accuracy: 0.6637 - val_loss: 1.9405
# Epoch 75/75
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9861 - loss: 0.0727
# Epoch 75: val_accuracy did not improve from 0.67010
# 449/449 ━━━━━━━━━━━━━━━━━━━━ 1329s 3s/step - accuracy: 0.9861 - loss: 0.0727 - val_accuracy: 0.6537 - val_loss: 1.9877

# %%
# Plotting Training and Validation Accuracy
f, ax = plt.subplots(figsize=(6, 3))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Plotting Training and Validation Loss
f, ax = plt.subplots(figsize=(6, 3))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
model =tf.keras.models.load_model('DNFer2013.keras')
# Make predictions on the validation set
y_pred = model.predict(X_val)
y_pred_classes = np.argmax(y_pred, axis=1)
y_true = np.argmax(y_val, axis=1)

# Generate the classification report
class_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']
report = classification_report(y_true, y_pred_classes, target_names=class_labels)
print("Classification Report:\n", report)

# Generate the confusion matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_true, y_pred_classes)
cm

labels=['angry','disgust','fear','happy','neutral','sad','surprise']
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# 113/113 ━━━━━━━━━━━━━━━━━━━━ 69s 568ms/step
# Classification Report:
#                precision    recall  f1-score   support
#
#        angry       0.66      0.54      0.59       467
#      disgust       0.85      0.59      0.69        56
#         fear       0.54      0.54      0.54       496
#        happy       0.79      0.88      0.83       895
#          sad       0.56      0.53      0.55       653
#     surprise       0.83      0.80      0.82       415
#      neutral       0.58      0.63      0.60       607
#
#     accuracy                           0.67      3589
#    macro avg       0.69      0.64      0.66      3589
# weighted avg       0.67      0.67      0.67      3589

# %%
# Ensure you have matplotlib installed, otherwise install it using pip
# pip install matplotlib

import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input

def preprocess_image(image_path, target_size=(96,96)):
    img = load_img(image_path, target_size=target_size)
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    return img, img_array  # Return both the PIL image and the preprocessed array

# Now you can use the preprocess_image function
original_img, img_array = preprocess_image('12_21.jpg')
prediction = model.predict(img_array)

# Get the index of the highest probability in the prediction
predicted_index = np.argmax(prediction)

# Assuming you have a list of class labels
class_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']  # Example labels

# Map the predicted index to the corresponding label
predicted_label = class_labels[predicted_index]

# Print the predicted label as a string
print(f"Predicted Emotion: {predicted_label}")

# Display the image using matplotlib
plt.imshow(original_img)
plt.title(f"Predicted Emotion: {predicted_label}")
plt.axis('off')  # Turn off the axis
plt.show()  # Display the plot
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step
# Predicted Emotion: surprise

# %%
# Ensure you have matplotlib installed, otherwise install it using pip
# pip install matplotlib

import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input

def preprocess_image(image_path, target_size=(96,96)):
    img = load_img(image_path, target_size=target_size)
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    return img, img_array  # Return both the PIL image and the preprocessed array

# Now you can use the preprocess_image function
original_img, img_array = preprocess_image('PrivateTest_20588149.jpg')
prediction = model.predict(img_array)

# Get the index of the highest probability in the prediction
predicted_index = np.argmax(prediction)

# Assuming you have a list of class labels
class_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']  # Example labels

# Map the predicted index to the corresponding label
predicted_label = class_labels[predicted_index]

# Print the predicted label as a string
print(f"Predicted Emotion: {predicted_label}")

# Display the image using matplotlib
plt.imshow(original_img)
plt.title(f"Predicted Emotion: {predicted_label}")
plt.axis('off')  # Turn off the axis
plt.show()  # Display the plot
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step
# Predicted Emotion: surprise
