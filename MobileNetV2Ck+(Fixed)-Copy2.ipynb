# %%
import os

from platform import python_version
import warnings
import time
import datetime as dt
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
import multiprocessing as mp
import shutil

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

import tensorflow as tf
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import MobileNetV2
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.utils import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.initializers import *
from tensorflow.keras import regularizers

import pandas as pd
import numpy as np
import seaborn as sns
from plotly.subplots import make_subplots
import plotly.graph_objects as go

from PIL import Image
import xml.etree.ElementTree as ET
import psutil
import random

warnings.filterwarnings("ignore")
# %matplotlib inline

# %%
img_size = 96
epochs = 75
batch_size = 48
testsplit = .2
targetx = 96
targety = 96
learning_rate = 0.0001
classes = 7
seed = 23
print(seed)

data_dir = "CK+MF/Female"
# Out:
# 23

# %%
train_datagen = ImageDataGenerator(
        rescale=1./255,
        brightness_range=[0.9,1.1],
        horizontal_flip=True,
        fill_mode='nearest',
    validation_split=testsplit
)


train_generator = train_datagen.flow_from_directory(
        data_dir,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=True,
        seed=seed,
       subset="training"
)
val_generator = train_datagen.flow_from_directory(
        data_dir,
        target_size=(targetx, targety),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle=False,
        seed=seed,
     subset="validation",
        
)
# Out:
# Found 496 images belonging to 7 classes.
# Found 121 images belonging to 7 classes.

# %%
from tensorflow.keras.callbacks import *
checkpoint = ModelCheckpoint('MNV2CKFemalemodel.keras',
                             monitor='val_accuracy',
                             save_best_only=True,
                             verbose=1,
                             mode='auto',
                             save_weights_only=False,
                             save_freq=1)

# %%
base_model = MobileNetV2(include_top=False, weights='imagenet', input_shape=(targetx, targety, 3))

x = base_model.output
x = GlobalAveragePooling2D()(x)
x = Flatten() (x)
x = BatchNormalization()(x)
x=Dropout(0.3)(x)
x = Dense(512, activation='relu',  kernel_initializer=glorot_uniform(seed),kernel_regularizer=regularizers.L2(0.001),activity_regularizer=regularizers.L2(1e-4), bias_initializer='zeros')(x)
x = BatchNormalization()(x)
x=Dropout(0.3)(x)
x = Dense(256, activation='relu',  kernel_initializer=glorot_uniform(seed),kernel_regularizer=regularizers.L2(0.001),activity_regularizer=regularizers.L2(1e-4), bias_initializer='zeros')(x)
x = BatchNormalization()(x)
x=Dropout(0.3)(x)
x = Dense(128, activation='relu',  kernel_initializer=glorot_uniform(seed),kernel_regularizer=regularizers.L2(0.001),activity_regularizer=regularizers.L2(1e-4), bias_initializer='zeros')(x)
x = BatchNormalization()(x)
x=Dropout(0.3)(x)
predictions = Dense(classes, activation='softmax', kernel_initializer='random_uniform', bias_initializer='zeros')(x)

model = tf.keras.Model(inputs=base_model.input, outputs=predictions)
optimizer = Adam(learning_rate=learning_rate)
loss = "categorical_crossentropy"

for layer in model.layers:
    layer.trainable = True

model.compile(optimizer=optimizer,
              loss=loss,
              metrics=["accuracy"])

# %%
# Check data generators
print(f"Number of training samples: {len(train_generator)}")
print(f"Number of validation samples: {len(val_generator)}")

# Check class indices
print(f"Training class indices: {train_generator.class_indices}")
print(f"Validation class indices: {val_generator.class_indices}")

# Ensure correct optimizer and loss function
optimizer = Adam(learning_rate=0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

# Ensure ModelCheckpoint is correctly configured
checkpoint = ModelCheckpoint('MNV2CKFemalemodel.keras', monitor='val_accuracy', save_best_only=True, verbose=1)

# Train the model with callbacks
history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=75,
    callbacks=[checkpoint]
)
# Out:
# Number of training samples: 11
# Number of validation samples: 3
# Training class indices: {'anger': 0, 'contempt': 1, 'disgust': 2, 'fear': 3, 'happy': 4, 'sadness': 5, 'surprise': 6}
# Validation class indices: {'anger': 0, 'contempt': 1, 'disgust': 2, 'fear': 3, 'happy': 4, 'sadness': 5, 'surprise': 6}
# Epoch 1/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 388ms/step - accuracy: 0.1476 - loss: 7.1989
# Epoch 1: val_accuracy improved from -inf to 0.04132, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 55s 740ms/step - accuracy: 0.1493 - loss: 7.1957 - val_accuracy: 0.0413 - val_loss: 5.2140
# Epoch 2/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.2097 - loss: 7.1295
# Epoch 2: val_accuracy improved from 0.04132 to 0.09091, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 451ms/step - accuracy: 0.2106 - loss: 7.1183 - val_accuracy: 0.0909 - val_loss: 5.2573
# Epoch 3/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.3112 - loss: 6.5976
# Epoch 3: val_accuracy improved from 0.09091 to 0.12397, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 445ms/step - accuracy: 0.3113 - loss: 6.6161 - val_accuracy: 0.1240 - val_loss: 5.2552
# Epoch 4/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.4051 - loss: 6.6524
# Epoch 4: val_accuracy improved from 0.12397 to 0.19835, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 444ms/step - accuracy: 0.4041 - loss: 6.6538 - val_accuracy: 0.1983 - val_loss: 5.2724
# Epoch 5/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.4503 - loss: 6.7548
# Epoch 5: val_accuracy improved from 0.19835 to 0.21488, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 451ms/step - accuracy: 0.4504 - loss: 6.7389 - val_accuracy: 0.2149 - val_loss: 5.1966
# Epoch 6/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.4768 - loss: 6.5490
# Epoch 6: val_accuracy improved from 0.21488 to 0.23967, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 447ms/step - accuracy: 0.4775 - loss: 6.5373 - val_accuracy: 0.2397 - val_loss: 5.1998
# Epoch 7/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.5302 - loss: 6.3642
# Epoch 7: val_accuracy did not improve from 0.23967
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 391ms/step - accuracy: 0.5302 - loss: 6.3617 - val_accuracy: 0.2314 - val_loss: 5.2891
# Epoch 8/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.5715 - loss: 6.2474
# Epoch 8: val_accuracy improved from 0.23967 to 0.28099, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 440ms/step - accuracy: 0.5725 - loss: 6.2409 - val_accuracy: 0.2810 - val_loss: 5.3246
# Epoch 9/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.6182 - loss: 6.0632
# Epoch 9: val_accuracy improved from 0.28099 to 0.30579, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 452ms/step - accuracy: 0.6184 - loss: 6.0646 - val_accuracy: 0.3058 - val_loss: 5.3870
# Epoch 10/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.6812 - loss: 6.1024
# Epoch 10: val_accuracy improved from 0.30579 to 0.34711, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - accuracy: 0.6811 - loss: 6.0929 - val_accuracy: 0.3471 - val_loss: 5.4087
# Epoch 11/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.6927 - loss: 6.1072
# Epoch 11: val_accuracy improved from 0.34711 to 0.39669, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - accuracy: 0.6938 - loss: 6.0889 - val_accuracy: 0.3967 - val_loss: 5.4052
# Epoch 12/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.7130 - loss: 5.9830
# Epoch 12: val_accuracy improved from 0.39669 to 0.42149, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 448ms/step - accuracy: 0.7134 - loss: 5.9670 - val_accuracy: 0.4215 - val_loss: 5.4710
# Epoch 13/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.7550 - loss: 5.8640
# Epoch 13: val_accuracy did not improve from 0.42149
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 390ms/step - accuracy: 0.7559 - loss: 5.8479 - val_accuracy: 0.3802 - val_loss: 5.4062
# Epoch 14/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.7467 - loss: 5.8174
# Epoch 14: val_accuracy did not improve from 0.42149
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 388ms/step - accuracy: 0.7474 - loss: 5.8016 - val_accuracy: 0.3802 - val_loss: 5.4156
# Epoch 15/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.7693 - loss: 5.6369
# Epoch 15: val_accuracy did not improve from 0.42149
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 383ms/step - accuracy: 0.7690 - loss: 5.6271 - val_accuracy: 0.4215 - val_loss: 5.3726
# Epoch 16/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.8305 - loss: 5.3348
# Epoch 16: val_accuracy did not improve from 0.42149
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 390ms/step - accuracy: 0.8315 - loss: 5.3409 - val_accuracy: 0.4132 - val_loss: 5.3543
# Epoch 17/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.8692 - loss: 5.3809
# Epoch 17: val_accuracy did not improve from 0.42149
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 386ms/step - accuracy: 0.8661 - loss: 5.3761 - val_accuracy: 0.3802 - val_loss: 5.3524
# Epoch 18/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.8429 - loss: 5.3625
# Epoch 18: val_accuracy did not improve from 0.42149
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 390ms/step - accuracy: 0.8426 - loss: 5.3497 - val_accuracy: 0.4050 - val_loss: 5.3699
# Epoch 19/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.8536 - loss: 5.1276
# Epoch 19: val_accuracy did not improve from 0.42149
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 389ms/step - accuracy: 0.8547 - loss: 5.1279 - val_accuracy: 0.4215 - val_loss: 5.4354
# Epoch 20/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step - accuracy: 0.8711 - loss: 4.8840
# Epoch 20: val_accuracy did not improve from 0.42149
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 394ms/step - accuracy: 0.8714 - loss: 4.8969 - val_accuracy: 0.4132 - val_loss: 5.4311
# Epoch 21/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.8744 - loss: 5.1356
# Epoch 21: val_accuracy did not improve from 0.42149
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 389ms/step - accuracy: 0.8730 - loss: 5.1235 - val_accuracy: 0.4132 - val_loss: 5.3781
# Epoch 22/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.8652 - loss: 5.0384
# Epoch 22: val_accuracy improved from 0.42149 to 0.43802, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 443ms/step - accuracy: 0.8645 - loss: 5.0239 - val_accuracy: 0.4380 - val_loss: 5.3891
# Epoch 23/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.8903 - loss: 4.8341
# Epoch 23: val_accuracy improved from 0.43802 to 0.47934, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 452ms/step - accuracy: 0.8914 - loss: 4.8309 - val_accuracy: 0.4793 - val_loss: 5.3848
# Epoch 24/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.8829 - loss: 4.7207
# Epoch 24: val_accuracy improved from 0.47934 to 0.48760, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 443ms/step - accuracy: 0.8826 - loss: 4.7200 - val_accuracy: 0.4876 - val_loss: 5.3236
# Epoch 25/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.8798 - loss: 4.8115
# Epoch 25: val_accuracy improved from 0.48760 to 0.57025, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 455ms/step - accuracy: 0.8794 - loss: 4.7991 - val_accuracy: 0.5702 - val_loss: 5.1717
# Epoch 26/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 365ms/step - accuracy: 0.8671 - loss: 4.6989
# Epoch 26: val_accuracy did not improve from 0.57025
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 396ms/step - accuracy: 0.8682 - loss: 4.6881 - val_accuracy: 0.5537 - val_loss: 5.0913
# Epoch 27/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.8739 - loss: 4.3675
# Epoch 27: val_accuracy did not improve from 0.57025
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 388ms/step - accuracy: 0.8747 - loss: 4.3783 - val_accuracy: 0.5702 - val_loss: 4.9359
# Epoch 28/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9088 - loss: 4.5544
# Epoch 28: val_accuracy did not improve from 0.57025
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 387ms/step - accuracy: 0.9080 - loss: 4.5449 - val_accuracy: 0.5620 - val_loss: 4.7448
# Epoch 29/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9043 - loss: 4.3466
# Epoch 29: val_accuracy did not improve from 0.57025
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 388ms/step - accuracy: 0.9045 - loss: 4.3467 - val_accuracy: 0.5702 - val_loss: 4.6369
# Epoch 30/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9231 - loss: 4.0014
# Epoch 30: val_accuracy improved from 0.57025 to 0.58678, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 471ms/step - accuracy: 0.9231 - loss: 4.0255 - val_accuracy: 0.5868 - val_loss: 4.5648
# Epoch 31/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.9403 - loss: 4.2763
# Epoch 31: val_accuracy improved from 0.58678 to 0.60331, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 443ms/step - accuracy: 0.9396 - loss: 4.2692 - val_accuracy: 0.6033 - val_loss: 4.4264
# Epoch 32/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9015 - loss: 4.2342
# Epoch 32: val_accuracy did not improve from 0.60331
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 391ms/step - accuracy: 0.9025 - loss: 4.2279 - val_accuracy: 0.6033 - val_loss: 4.3153
# Epoch 33/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9361 - loss: 3.9575
# Epoch 33: val_accuracy improved from 0.60331 to 0.61157, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 445ms/step - accuracy: 0.9352 - loss: 3.9677 - val_accuracy: 0.6116 - val_loss: 4.2942
# Epoch 34/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.9202 - loss: 3.9656
# Epoch 34: val_accuracy improved from 0.61157 to 0.61983, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 455ms/step - accuracy: 0.9210 - loss: 3.9695 - val_accuracy: 0.6198 - val_loss: 4.1952
# Epoch 35/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step - accuracy: 0.9470 - loss: 3.7962
# Epoch 35: val_accuracy did not improve from 0.61983
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 387ms/step - accuracy: 0.9472 - loss: 3.8075 - val_accuracy: 0.6033 - val_loss: 4.1364
# Epoch 36/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.9179 - loss: 3.6487
# Epoch 36: val_accuracy did not improve from 0.61983
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 408ms/step - accuracy: 0.9178 - loss: 3.6710 - val_accuracy: 0.6033 - val_loss: 4.0755
# Epoch 37/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9498 - loss: 3.9150
# Epoch 37: val_accuracy did not improve from 0.61983
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 388ms/step - accuracy: 0.9500 - loss: 3.9085 - val_accuracy: 0.5950 - val_loss: 4.0017
# Epoch 38/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.9541 - loss: 3.8746
# Epoch 38: val_accuracy did not improve from 0.61983
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 389ms/step - accuracy: 0.9530 - loss: 3.8683 - val_accuracy: 0.6116 - val_loss: 3.8824
# Epoch 39/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.9478 - loss: 3.6728
# Epoch 39: val_accuracy did not improve from 0.61983
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 395ms/step - accuracy: 0.9479 - loss: 3.6799 - val_accuracy: 0.6198 - val_loss: 3.7968
# Epoch 40/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.9689 - loss: 3.5374
# Epoch 40: val_accuracy improved from 0.61983 to 0.63636, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 448ms/step - accuracy: 0.9675 - loss: 3.5491 - val_accuracy: 0.6364 - val_loss: 3.7161
# Epoch 41/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.9351 - loss: 3.6896
# Epoch 41: val_accuracy did not improve from 0.63636
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 385ms/step - accuracy: 0.9350 - loss: 3.6839 - val_accuracy: 0.6364 - val_loss: 3.6959
# Epoch 42/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.9630 - loss: 3.6370
# Epoch 42: val_accuracy did not improve from 0.63636
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 394ms/step - accuracy: 0.9622 - loss: 3.6318 - val_accuracy: 0.6198 - val_loss: 3.6448
# Epoch 43/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.9458 - loss: 3.5750
# Epoch 43: val_accuracy improved from 0.63636 to 0.65289, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - accuracy: 0.9470 - loss: 3.5707 - val_accuracy: 0.6529 - val_loss: 3.5886
# Epoch 44/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step - accuracy: 0.9473 - loss: 3.5433
# Epoch 44: val_accuracy improved from 0.65289 to 0.66942, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 438ms/step - accuracy: 0.9473 - loss: 3.5397 - val_accuracy: 0.6694 - val_loss: 3.5169
# Epoch 45/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.9439 - loss: 3.2030
# Epoch 45: val_accuracy did not improve from 0.66942
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 410ms/step - accuracy: 0.9449 - loss: 3.2207 - val_accuracy: 0.6612 - val_loss: 3.4241
# Epoch 46/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.9351 - loss: 3.2265
# Epoch 46: val_accuracy did not improve from 0.66942
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 414ms/step - accuracy: 0.9363 - loss: 3.2423 - val_accuracy: 0.6612 - val_loss: 3.4122
# Epoch 47/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step - accuracy: 0.9353 - loss: 3.4325
# Epoch 47: val_accuracy did not improve from 0.66942
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 386ms/step - accuracy: 0.9363 - loss: 3.4260 - val_accuracy: 0.6529 - val_loss: 3.3997
# Epoch 48/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9588 - loss: 3.3045
# Epoch 48: val_accuracy did not improve from 0.66942
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 387ms/step - accuracy: 0.9590 - loss: 3.2995 - val_accuracy: 0.6694 - val_loss: 3.3643
# Epoch 49/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 384ms/step - accuracy: 0.9406 - loss: 3.0177
# Epoch 49: val_accuracy did not improve from 0.66942
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 413ms/step - accuracy: 0.9400 - loss: 3.0371 - val_accuracy: 0.6694 - val_loss: 3.2912
# Epoch 50/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9532 - loss: 3.2467
# Epoch 50: val_accuracy did not improve from 0.66942
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 390ms/step - accuracy: 0.9531 - loss: 3.2460 - val_accuracy: 0.6529 - val_loss: 3.2613
# Epoch 51/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 427ms/step - accuracy: 0.9464 - loss: 3.2453
# Epoch 51: val_accuracy did not improve from 0.66942
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 466ms/step - accuracy: 0.9460 - loss: 3.2399 - val_accuracy: 0.6446 - val_loss: 3.2353
# Epoch 52/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 361ms/step - accuracy: 0.9582 - loss: 3.1585
# Epoch 52: val_accuracy did not improve from 0.66942
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 393ms/step - accuracy: 0.9580 - loss: 3.1577 - val_accuracy: 0.6694 - val_loss: 3.1684
# Epoch 53/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.9616 - loss: 3.1193
# Epoch 53: val_accuracy did not improve from 0.66942
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 386ms/step - accuracy: 0.9609 - loss: 3.1183 - val_accuracy: 0.6612 - val_loss: 3.0692
# Epoch 54/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9677 - loss: 3.1350
# Epoch 54: val_accuracy did not improve from 0.66942
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 387ms/step - accuracy: 0.9677 - loss: 3.1265 - val_accuracy: 0.6694 - val_loss: 2.9801
# Epoch 55/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 355ms/step - accuracy: 0.9574 - loss: 3.1434
# Epoch 55: val_accuracy improved from 0.66942 to 0.67769, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 437ms/step - accuracy: 0.9561 - loss: 3.1370 - val_accuracy: 0.6777 - val_loss: 2.9058
# Epoch 56/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.9570 - loss: 3.0584
# Epoch 56: val_accuracy improved from 0.67769 to 0.68595, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 442ms/step - accuracy: 0.9579 - loss: 3.0575 - val_accuracy: 0.6860 - val_loss: 2.8853
# Epoch 57/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9643 - loss: 3.0258
# Epoch 57: val_accuracy did not improve from 0.68595
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 387ms/step - accuracy: 0.9639 - loss: 3.0251 - val_accuracy: 0.6694 - val_loss: 2.8279
# Epoch 58/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9414 - loss: 3.0041
# Epoch 58: val_accuracy did not improve from 0.68595
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 387ms/step - accuracy: 0.9423 - loss: 2.9976 - val_accuracy: 0.6860 - val_loss: 2.7665
# Epoch 59/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 367ms/step - accuracy: 0.9254 - loss: 3.0263
# Epoch 59: val_accuracy improved from 0.68595 to 0.69421, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 454ms/step - accuracy: 0.9274 - loss: 3.0165 - val_accuracy: 0.6942 - val_loss: 2.7549
# Epoch 60/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 360ms/step - accuracy: 0.9566 - loss: 2.8453
# Epoch 60: val_accuracy did not improve from 0.69421
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 390ms/step - accuracy: 0.9569 - loss: 2.8468 - val_accuracy: 0.6860 - val_loss: 2.7205
# Epoch 61/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.9867 - loss: 2.8191
# Epoch 61: val_accuracy did not improve from 0.69421
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 387ms/step - accuracy: 0.9856 - loss: 2.8199 - val_accuracy: 0.6777 - val_loss: 2.7012
# Epoch 62/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.9707 - loss: 2.9115
# Epoch 62: val_accuracy did not improve from 0.69421
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 387ms/step - accuracy: 0.9708 - loss: 2.9076 - val_accuracy: 0.6860 - val_loss: 2.6779
# Epoch 63/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step - accuracy: 0.9753 - loss: 2.7666
# Epoch 63: val_accuracy did not improve from 0.69421
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 393ms/step - accuracy: 0.9754 - loss: 2.7667 - val_accuracy: 0.6942 - val_loss: 2.6719
# Epoch 64/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step - accuracy: 0.9718 - loss: 2.7334
# Epoch 64: val_accuracy did not improve from 0.69421
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 386ms/step - accuracy: 0.9713 - loss: 2.7364 - val_accuracy: 0.6777 - val_loss: 2.6932
# Epoch 65/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 380ms/step - accuracy: 0.9377 - loss: 2.6293
# Epoch 65: val_accuracy did not improve from 0.69421
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 412ms/step - accuracy: 0.9399 - loss: 2.6385 - val_accuracy: 0.6942 - val_loss: 2.6359
# Epoch 66/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.9852 - loss: 2.7226
# Epoch 66: val_accuracy did not improve from 0.69421
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 390ms/step - accuracy: 0.9847 - loss: 2.7225 - val_accuracy: 0.6860 - val_loss: 2.5839
# Epoch 67/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step - accuracy: 0.9843 - loss: 2.7488
# Epoch 67: val_accuracy did not improve from 0.69421
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 393ms/step - accuracy: 0.9836 - loss: 2.7454 - val_accuracy: 0.6860 - val_loss: 2.5630
# Epoch 68/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 372ms/step - accuracy: 0.9799 - loss: 2.7362
# Epoch 68: val_accuracy did not improve from 0.69421
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 407ms/step - accuracy: 0.9794 - loss: 2.7315 - val_accuracy: 0.6860 - val_loss: 2.5583
# Epoch 69/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 378ms/step - accuracy: 0.9692 - loss: 2.6923
# Epoch 69: val_accuracy did not improve from 0.69421
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 407ms/step - accuracy: 0.9691 - loss: 2.6922 - val_accuracy: 0.6860 - val_loss: 2.5371
# Epoch 70/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 383ms/step - accuracy: 0.9370 - loss: 2.5520
# Epoch 70: val_accuracy improved from 0.69421 to 0.71901, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 471ms/step - accuracy: 0.9390 - loss: 2.5584 - val_accuracy: 0.7190 - val_loss: 2.4921
# Epoch 71/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step - accuracy: 0.9793 - loss: 2.7275
# Epoch 71: val_accuracy improved from 0.71901 to 0.73554, saving model to MNV2CKFemalemodel.keras
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 439ms/step - accuracy: 0.9793 - loss: 2.7192 - val_accuracy: 0.7355 - val_loss: 2.4328
# Epoch 72/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 371ms/step - accuracy: 0.9585 - loss: 2.6338
# Epoch 72: val_accuracy did not improve from 0.73554
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 404ms/step - accuracy: 0.9586 - loss: 2.6310 - val_accuracy: 0.7190 - val_loss: 2.4223
# Epoch 73/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 382ms/step - accuracy: 0.9764 - loss: 2.5705
# Epoch 73: val_accuracy did not improve from 0.73554
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 413ms/step - accuracy: 0.9765 - loss: 2.5681 - val_accuracy: 0.7190 - val_loss: 2.4424
# Epoch 74/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 358ms/step - accuracy: 0.9670 - loss: 2.6145
# Epoch 74: val_accuracy did not improve from 0.73554
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 388ms/step - accuracy: 0.9671 - loss: 2.6125 - val_accuracy: 0.7190 - val_loss: 2.4137
# Epoch 75/75
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step - accuracy: 0.9698 - loss: 2.4809
# Epoch 75: val_accuracy did not improve from 0.73554
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 5s 388ms/step - accuracy: 0.9703 - loss: 2.4849 - val_accuracy: 0.7107 - val_loss: 2.3895

# %%
f, ax=plt.subplots(figsize=(6,3))
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Training and Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
f, ax=plt.subplots(figsize=(6,3))
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Training and Validation Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend()
plt.show()

# %%
import tensorflow as tf
model =tf.keras.models.load_model('MNV2CKFemalemodel.keras')
predictions = model.predict(val_generator, steps=len(val_generator))
y = np.argmax(predictions, axis=1)

print('Classification Report')
cr = classification_report(y_true=val_generator.classes, y_pred=y, target_names=val_generator.class_indices)
print(cr)
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 4s 1s/step
# Classification Report
#               precision    recall  f1-score   support
#
#        anger       0.00      0.00      0.00        15
#     contempt       0.57      0.57      0.57         7
#      disgust       0.57      1.00      0.73        20
#         fear       0.67      0.40      0.50        10
#        happy       0.74      1.00      0.85        28
#      sadness       0.00      0.00      0.00        10
#     surprise       0.89      1.00      0.94        31
#
#     accuracy                           0.72       121
#    macro avg       0.49      0.57      0.51       121
# weighted avg       0.58      0.72      0.63       121

# %%
Y_pred = model.predict(val_generator)
y_pred = np.argmax(Y_pred, axis=1)
y_true=val_generator.classes

from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_true,y_pred)
cm

labels=['angry','disgust','fear','happy','neutral','sad','surprise']
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)

disp.plot(cmap=plt.cm.Blues)
plt.show()
# Out:
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 72ms/step

# %%
# Ensure you have matplotlib installed, otherwise install it using pip
# pip install matplotlib

import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input

def preprocess_image(image_path, target_size=(96,96)):
    img = load_img(image_path, target_size=target_size)
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    return img, img_array  # Return both the PIL image and the preprocessed array

# Now you can use the preprocess_image function
original_img, img_array = preprocess_image('12_21.jpg')
prediction = model.predict(img_array)

# Get the index of the highest probability in the prediction
predicted_index = np.argmax(prediction)

# Assuming you have a list of class labels
class_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']  # Example labels

# Map the predicted index to the corresponding label
predicted_label = class_labels[predicted_index]

# Print the predicted label as a string
print(f"Predicted Emotion: {predicted_label}")

# Display the image using matplotlib
plt.imshow(original_img)
plt.title(f"Predicted Emotion: {predicted_label}")
plt.axis('off')  # Turn off the axis
plt.show()  # Display the plot
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Predicted Emotion: fear

# %%
# Ensure you have matplotlib installed, otherwise install it using pip
# pip install matplotlib

import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.applications.vgg16 import preprocess_input

def preprocess_image(image_path, target_size=(96,96)):
    img = load_img(image_path, target_size=target_size)
    img_array = img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)
    img_array = preprocess_input(img_array)
    return img, img_array  # Return both the PIL image and the preprocessed array

# Now you can use the preprocess_image function
original_img, img_array = preprocess_image('0_29.jpg')
prediction = model.predict(img_array)

# Get the index of the highest probability in the prediction
predicted_index = np.argmax(prediction)

# Assuming you have a list of class labels
class_labels = ['angry', 'disgust', 'fear', 'happy', 'sad', 'surprise', 'neutral']  # Example labels

# Map the predicted index to the corresponding label
predicted_label = class_labels[predicted_index]

# Print the predicted label as a string
print(f"Predicted Emotion: {predicted_label}")

# Display the image using matplotlib
plt.imshow(original_img)
plt.title(f"Predicted Emotion: {predicted_label}")
plt.axis('off')  # Turn off the axis
plt.show()  # Display the plot
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# Predicted Emotion: fear
